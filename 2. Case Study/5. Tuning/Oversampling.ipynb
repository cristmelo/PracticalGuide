# %%
# %run auxiliary.ipynb

# %%
all_df = pd.read_csv('wo_outliers.csv') # Original dataa

# %%
results_dict = dict()

# %%
k_fold = StratifiedKFold(10)

X_features = ['CBO','CC','LCOM','WMC']

X = pd.DataFrame(all_df.loc[:, X_features])

y = pd.DataFrame(all_df.loc[:, 'will_change'])
X = X.rename(columns={'CBO':'f0', 'CC':'f1', 'LCOM':'f2', 'WMC':'f3'})

# %%
X.head()
# Out:
#          f0        f1   f2        f3
# 0  0.000000  0.004098  0.0  0.017857
# 1  0.000000  0.004098  0.0  0.017857
# 2  0.129630  0.018443  0.0  0.071429
# 3  0.006173  0.014344  0.0  0.035714
# 4  0.006173  0.004098  0.0  0.017857

# %%
parameters_svc_linear = {
        'clf__kernel':['linear'],
        'clf__C': [0.002, 1, 512, 1024, 2048], 
        'clf__class_weight':[{1:1}, {1:10}, {1:15}, {1:20}],
        'clf__max_iter': [10000]
    }

parameters_svc_rbf = {
        'clf__kernel':['rbf'],
        'clf__C': [0.002, 1, 512, 1024, 2048], 
        'clf__class_weight':[{1:1}, {1:10}, {1:15}, {1:20}],
        'clf__max_iter': [10000]
    }

parameters_dtc_grid = {
    'clf__criterion':('gini', 'entropy'), 
    'clf__min_samples_split':[0.1, 0.2, 0.3], 
    'clf__max_depth': [1, 10, 30, None],
    'clf__class_weight':[{1:1}, {1:10}, {1:20}, 'balanced'],
    'clf__presort':[False, True],
}

parameters_rfc_grid = { 
    'clf__n_estimators': [10, 50, 90],
    'clf__max_features': ['sqrt', 'log2'],
    'clf__max_depth' : [1, 10, 30, None],
    'clf__min_samples_split': [2, 8, 16],
    'clf__criterion' :['gini', 'entropy'],
    'clf__class_weight':[ {1:1}, {1:10}, {1:15}, {1:20}]
}

parameters_ABC_grid = {
    'clf__base_estimator__criterion' : ["gini", "entropy"],
    'clf__base_estimator__splitter' :   ["best", "random"],
    'clf__base_estimator__max_depth' : [1, 10, 30, None], 
    'clf__base_estimator__class_weight': [{1:1}, {1:10}, {1:15}, {1:20}], 
    'clf__n_estimators':  [10, 50, 90],
}


parameters_knn_grid = {'clf__n_neighbors': list(range(1,30))}


penalty = ['l1', 'l2']
C = np.logspace(0, 4, 10)
parameters_lr_grid = [{'clf__C': np.logspace(0, 10, 25), 
                        'clf__penalty':['l1', 'l2'],
                        }]

parameters_GBC = {
    "clf__loss":["deviance"],
    "clf__learning_rate": [0.01, 0.025, 0.05],
    "clf__max_depth": [None, 2, 4, 6, 10],
    "clf__max_features":["log2","sqrt"],
    "clf__criterion": ["friedman_mse",  "mae"],
    'clf__n_estimators': [64, 128, 256, 512] #[1, 2, 4, 16, 32, 64, 128, 256, 512]
    }


param_xgb_grid = {
           'clf__clf__n_estimators':  [10, 50, 90],
           'clf__clf__max_depth' : [1, 10, 30, None],
           'clf__learning_rate': [0.0001],
           'clf__min_child_weight': [1], #tuning min_child_weight subsample colsample_bytree for fighting against overfit
           'clf__random_state': [42] #ensemble xgboost with multiple seeds may reduce variance
             }

param_lgm_grid = {
    "clf__clf__random_state":[42]
}

# %% [markdown]
# # SMOTE

# %%
sampler = SMOTE(random_state=42)

# %% [markdown]
# ## Light GBM

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', lbm.LGBMClassifier())
    ])


clf = GridSearchCV(base_clf, param_lgm_grid, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Light GBM - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Light GBM - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Logistic Regression

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', LogisticRegression(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_lr_grid, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Logistic Regression - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Logistic Regression - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - Linear

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_linear, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM Linear - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM Linear - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - RBF

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_rbf, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM RBF - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM RBF - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Decision Tree

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', DecisionTreeClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_dtc_grid, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Decision Tree - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Decision Tree - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Random Forest

# %% [markdown]
# %%time
#
#
# base_clf = Pipeline([
#         ('sampling', sampler),
#         ('clf', RandomForestClassifier(random_state=42))
#     ])
#
# clf = GridSearchCV(base_clf, parameters_rfc_grid, cv=10, scoring='roc_auc', n_jobs=-1)
#
# scores_list = list()
#
# results_dict['Random Forest - SMOTE'] = dict()
#
# for k, (train, test) in enumerate(k_fold.split(X, y)):
#     clf.fit(X.iloc[train], y.iloc[train])
#
#     print('Fold: ' + str(k + 1))
#
#     print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
#     print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
#     cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
#     cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
#     print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
#
#     results_dict['Random Forest - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),
#                                                              str(clf.get_params()['estimator']),
#                                                              '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
#
#     scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
#
# print('Mean: ' + str(np.mean(scores_list)))
# print('Std deviation: ' + str(np.std(scores_list)))

# %% [markdown]
# with open('partial_results_oversampling.pickle', 'wb') as handle:
#     pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## KNN

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', KNeighborsClassifier())
    ])

clf = GridSearchCV(base_clf, parameters_knn_grid, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['KNN - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['KNN - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6824554755589238
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8131868131868132, 0.55]
# Fold: 2
# ROC_AUC: 0.7117279272451686
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.6648351648351648, 0.76]
# Fold: 3
# ROC_AUC: 0.5979064039408867
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.6785714285714286, 0.52]
# Fold: 4
# ROC_AUC: 0.6211159530125048
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7939560439560439, 0.45]
# Fold: 5
# ROC_AUC: 0.6613774156877605
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.6675824175824175, 0.66]
# Fold: 6
# ROC_AUC: 0.6174213717317165
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.5796703296703297, 0.66]
# Fold: 7
# ROC_AUC: 0.6238158393330807
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.489010989010989, 0.76]
# Fold: 8
# ROC_AUC: 0.679702872884691
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8236914600550964, 0.54]
# Fold: 9
# ROC_AUC: 0.7455234159779616
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7410468319559229, 0.75]
# Fold: 10
# ROC_AUC: 0.6138331365604094
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8705234159779615, 0.36]
# Mean: 0.6554879811933104
# Std deviation: 0.04615408431208693
# Wall time: 1min 32s

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Adaboost

# %% [markdown]
# %%time
#
# adaboost_base = DecisionTreeClassifier(random_state = 42)
#
# base_clf = Pipeline([
#         ('sampling', sampler),
#         ('clf', AdaBoostClassifier(random_state=42, base_estimator=adaboost_base))
#     ])
#
# clf = GridSearchCV(base_clf, parameters_ABC_grid, cv=10, scoring='roc_auc', n_jobs=-1)
#
# scores_list = list()
#
# results_dict['Adaboost - SMOTE'] = dict()
#
# for k, (train, test) in enumerate(k_fold.split(X, y)):
#     clf.fit(X.iloc[train], y.iloc[train])
#
#     print('Fold: ' + str(k + 1))
#
#     print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
#     print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
#     cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
#     cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
#     print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
#
#     results_dict['Adaboost - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),
#                                                              str(clf.get_params()['estimator']),
#                                                              '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
#
#     scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
#
# print('Mean: ' + str(np.mean(scores_list)))
# print('Std deviation: ' + str(np.std(scores_list)))

# %% [markdown]
# with open('partial_results_oversampling.pickle', 'wb') as handle:
#     pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Gradient Boost

# %% [markdown]
# %%time
#
# base_clf = Pipeline([
#         ('sampling', sampler),
#         ('clf', GradientBoostingClassifier(random_state=42))
#     ])
#
#
# clf = GridSearchCV(base_clf, parameters_GBC, cv=10, scoring='roc_auc', n_jobs=-1)
#
#
# scores_list = list()
#
# results_dict['Gradient Boost - SMOTE'] = dict()
#
# for k, (train, test) in enumerate(k_fold.split(X, y)):
#     clf.fit(X.iloc[train], y.iloc[train])
#
#     print('Fold: ' + str(k + 1))
#
#     print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
#     print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
#     cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
#     cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
#     print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
#
#     results_dict['Gradient Boost - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),
#                                                              str(clf.get_params()['estimator']),
#                                                              '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
#
#     scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
#
# print('Mean: ' + str(np.mean(scores_list)))
# print('Std deviation: ' + str(np.std(scores_list)))

# %% [markdown]
# with open('partial_results_oversampling.pickle', 'wb') as handle:
#     pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## XGBoost

# %%
# %%time


base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', xgb.XGBClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, param_xgb_grid, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['XGBoost - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['XGBoost - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6940602500947328
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8708791208791209, 0.52]
# Fold: 2
# ROC_AUC: 0.779651383099659
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8351648351648352, 0.72]
# Fold: 3
# ROC_AUC: 0.6722243273967412
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7582417582417582, 0.59]
# Fold: 4
# ROC_AUC: 0.6363679424024251
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7554945054945055, 0.52]
# Fold: 5
# ROC_AUC: 0.6025009473285334
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7912087912087912, 0.41]
# Fold: 6
# ROC_AUC: 0.5377510420613869
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.42032967032967034, 0.66]
# Fold: 7
# ROC_AUC: 0.6867184539598332
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7527472527472527, 0.62]
# Fold: 8
# ROC_AUC: 0.7068575364029909
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.5922865013774105, 0.82]
# Fold: 9
# ROC_AUC: 0.6466942148760331
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7933884297520661, 0.5]
# Fold: 10
# ROC_AUC: 0.5520956316410862
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9256198347107438, 0.18]
# Mean: 0.6514921729263421
# Std deviation: 0.06959991460431386
# Wall time: 2min 48s

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # ADASYN

# %%
sampler = ADASYN(random_state=42)

# %% [markdown]
# ## Light GBM

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', lbm.LGBMClassifier())
    ])


clf = GridSearchCV(base_clf, param_lgm_grid, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Light GBM - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Light GBM - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.624194770746495
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9725274725274725, 0.28]
# Fold: 2
# ROC_AUC: 0.627084122773778
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9093406593406593, 0.34]
# Fold: 3
# ROC_AUC: 0.59184350132626
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9423076923076923, 0.24]
# Fold: 4
# ROC_AUC: 0.6097006441834029
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.978021978021978, 0.24]
# Fold: 5
# ROC_AUC: 0.5836017430845017
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9258241758241759, 0.24]
# Fold: 6
# ROC_AUC: 0.5395035998484274
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9065934065934066, 0.17]
# Fold: 7
# ROC_AUC: 0.6961917392951875
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8406593406593407, 0.55]
# Fold: 8
# ROC_AUC: 0.6798996458087366
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9669421487603306, 0.39]
# Fold: 9
# ROC_AUC: 0.662042502951594
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9669421487603306, 0.36]
# Fold: 10
# ROC_AUC: 0.5178079496261314
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9641873278236914, 0.07]
# Mean: 0.6131870219644513
# Std deviation: 0.05469087566541502
# Wall time: 12.5 s

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Logistic Regression

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', LogisticRegression(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_lr_grid, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Logistic Regression - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Logistic Regression - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6534672224327397
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8241758241758241, 0.48]
# Fold: 2
# ROC_AUC: 0.7846722243273967
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7417582417582418, 0.83]
# Fold: 3
# ROC_AUC: 0.6812239484653277
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7417582417582418, 0.62]
# Fold: 4
# ROC_AUC: 0.7140488821523304
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8763736263736264, 0.55]
# Fold: 5
# ROC_AUC: 0.5861595301250474
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6895604395604396, 0.48]
# Fold: 6
# ROC_AUC: 0.5730390299355816
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6978021978021978, 0.45]
# Fold: 7
# ROC_AUC: 0.6979916635089047
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6373626373626373, 0.76]
# Fold: 8
# ROC_AUC: 0.7800570641479733
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8815426997245179, 0.68]
# Fold: 9
# ROC_AUC: 0.784090909090909
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8181818181818182, 0.75]
# Fold: 10
# ROC_AUC: 0.6908205430932705
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9173553719008265, 0.46]
# Mean: 0.6945571017279482
# Std deviation: 0.07227433541927392
# Wall time: 1min 25s

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - Linear

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_linear, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM Linear - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM Linear - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6423361121636983
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8708791208791209, 0.41]
# Fold: 2
# ROC_AUC: 0.7878931413414171
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8516483516483516, 0.72]
# Fold: 3
# ROC_AUC: 0.7065649867374005
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8269230769230769, 0.59]
# Fold: 4
# ROC_AUC: 0.6884236453201971
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9285714285714286, 0.45]
# Fold: 5
# ROC_AUC: 0.5652709359605912
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7857142857142857, 0.34]
# Fold: 6
# ROC_AUC: 0.5917961348995832
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.6318681318681318, 0.55]
# Fold: 7
# ROC_AUC: 0.7474422129594543
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7362637362637363, 0.76]
# Fold: 8
# ROC_AUC: 0.7594451003541912
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8760330578512396, 0.64]
# Fold: 9
# ROC_AUC: 0.6866391184573003
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8732782369146006, 0.5]
# Fold: 10
# ROC_AUC: 0.538124754033845
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7548209366391184, 0.32]
# Mean: 0.6713936142227678
# Std deviation: 0.08066645850652678
# Wall time: 13min 36s

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - RBF

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_rbf, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM RBF - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM RBF - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6395888594164456
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8653846153846154, 0.41]
# Fold: 2
# ROC_AUC: 0.7790356195528609
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7994505494505495, 0.76]
# Fold: 3
# ROC_AUC: 0.6708507010231148
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7554945054945055, 0.59]
# Fold: 4
# ROC_AUC: 0.7174118984463811
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9175824175824175, 0.52]
# Fold: 5
# ROC_AUC: 0.6197423266388783
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7912087912087912, 0.45]
# Fold: 6
# ROC_AUC: 0.6584880636604775
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7307692307692307, 0.59]
# Fold: 7
# ROC_AUC: 0.6786187949981055
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.6675824175824175, 0.69]
# Fold: 8
# ROC_AUC: 0.6189492325855963
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.5950413223140496, 0.64]
# Fold: 9
# ROC_AUC: 0.7154663518299882
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.859504132231405, 0.57]
# Fold: 10
# ROC_AUC: 0.6276564344746163
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9338842975206612, 0.32]
# Mean: 0.6725808282626465
# Std deviation: 0.049188005087709076
# Wall time: 20min 3s

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Decision Tree

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', DecisionTreeClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_dtc_grid, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Decision Tree - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Decision Tree - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6824554755589238
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8131868131868132, 0.55]
# Fold: 2
# ROC_AUC: 0.6970917014020462
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.739010989010989, 0.66]
# Fold: 3
# ROC_AUC: 0.7257483895414929
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.554945054945055, 0.9]
# Fold: 4
# ROC_AUC: 0.6562144751799924
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8296703296703297, 0.48]
# Fold: 5
# ROC_AUC: 0.587675255778704
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.6236263736263736, 0.55]
# Fold: 6
# ROC_AUC: 0.6131583933308071
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.6401098901098901, 0.59]
# Fold: 7
# ROC_AUC: 0.6795187571049641
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.5659340659340659, 0.79]
# Fold: 8
# ROC_AUC: 0.7346025186934279
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.790633608815427, 0.68]
# Fold: 9
# ROC_AUC: 0.7193526170798898
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.6887052341597796, 0.75]
# Fold: 10
# ROC_AUC: 0.7786304604486423
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8429752066115702, 0.71]
# Mean: 0.687444804411889
# Std deviation: 0.0544541021831343
# Wall time: 5min 8s

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Random Forest

# %% [markdown]
# %%time
#
#
# base_clf = Pipeline([
#         ('sampling', sampler),
#         ('clf', RandomForestClassifier(random_state=42))
#     ])
#
# clf = GridSearchCV(base_clf, parameters_rfc_grid, cv=10, scoring='roc_auc', n_jobs=-1)
#
# scores_list = list()
#
# results_dict['Random Forest - ADASYN'] = dict()
#
# for k, (train, test) in enumerate(k_fold.split(X, y)):
#     clf.fit(X.iloc[train], y.iloc[train])
#
#     print('Fold: ' + str(k + 1))
#
#     print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
#     print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
#     cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
#     cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
#     print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
#
#     results_dict['Random Forest - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),
#                                                              str(clf.get_params()['estimator']),
#                                                              '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
#
#     scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
#
# print('Mean: ' + str(np.mean(scores_list)))
# print('Std deviation: ' + str(np.std(scores_list)))

# %% [markdown]
# with open('partial_results_oversampling.pickle', 'wb') as handle:
#     pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## KNN

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', KNeighborsClassifier())
    ])

clf = GridSearchCV(base_clf, parameters_knn_grid, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['KNN - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['KNN - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6473569533914362
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7774725274725275, 0.52]
# Fold: 2
# ROC_AUC: 0.6532777567260326
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.5824175824175825, 0.72]
# Fold: 3
# ROC_AUC: 0.5972906403940886
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.6428571428571429, 0.55]
# Fold: 4
# ROC_AUC: 0.6618510799545283
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.771978021978022, 0.55]
# Fold: 5
# ROC_AUC: 0.6366521409624859
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.6181318681318682, 0.66]
# Fold: 6
# ROC_AUC: 0.6531356574460022
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.6510989010989011, 0.66]
# Fold: 7
# ROC_AUC: 0.6375521030693444
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.5164835164835165, 0.76]
# Fold: 8
# ROC_AUC: 0.6755706414797324
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8154269972451791, 0.54]
# Fold: 9
# ROC_AUC: 0.7111865407319953
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.743801652892562, 0.68]
# Fold: 10
# ROC_AUC: 0.5890397481306572
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8209366391184573, 0.36]
# Mean: 0.6462913262286303
# Std deviation: 0.033549459110642346
# Wall time: 1min 40s

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Adaboost

# %% [markdown]
# %%time
#
# adaboost_base = DecisionTreeClassifier(random_state = 42)
#
# base_clf = Pipeline([
#         ('sampling', sampler),
#         ('clf', AdaBoostClassifier(random_state=42, base_estimator=adaboost_base))
#     ])
#
# clf = GridSearchCV(base_clf, parameters_ABC_grid, cv=10, scoring='roc_auc', n_jobs=-1)
#
# scores_list = list()
#
# results_dict['Adaboost - ADASYN'] = dict()
#
# for k, (train, test) in enumerate(k_fold.split(X, y)):
#     clf.fit(X.iloc[train], y.iloc[train])
#
#     print('Fold: ' + str(k + 1))
#
#     print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
#     print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
#     cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
#     cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
#     print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
#
#     results_dict['Adaboost - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),
#                                                              str(clf.get_params()['estimator']),
#                                                              '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
#
#     scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
#
# print('Mean: ' + str(np.mean(scores_list)))
# print('Std deviation: ' + str(np.std(scores_list)))

# %% [markdown]
# with open('partial_results_oversampling.pickle', 'wb') as handle:
#     pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Gradient Boost

# %% [markdown]
# %%time
#
# base_clf = Pipeline([
#         ('sampling', sampler),
#         ('clf', GradientBoostingClassifier(random_state=42))
#     ])
#
#
# clf = GridSearchCV(base_clf, parameters_GBC, cv=10, scoring='roc_auc', n_jobs=-1)
#
#
# scores_list = list()
#
# results_dict['Gradient Boost - ADASYN'] = dict()
#
# for k, (train, test) in enumerate(k_fold.split(X, y)):
#     clf.fit(X.iloc[train], y.iloc[train])
#
#     print('Fold: ' + str(k + 1))
#
#     print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
#     print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
#     cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
#     cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
#     print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
#
#     results_dict['Gradient Boost - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),
#                                                              str(clf.get_params()['estimator']),
#                                                              '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
#
#     scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
#
# print('Mean: ' + str(np.mean(scores_list)))
# print('Std deviation: ' + str(np.std(scores_list)))

# %% [markdown]
# with open('partial_results_oversampling.pickle', 'wb') as handle:
#     pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## XGBoost

# %%
# %%time


base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', xgb.XGBClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, param_xgb_grid, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['XGBoost - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['XGBoost - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6456517620310724
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.6016483516483516, 0.69]
# Fold: 2
# ROC_AUC: 0.6917392951875709
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.6593406593406593, 0.72]
# Fold: 3
# ROC_AUC: 0.6982758620689655
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.5, 0.9]
# Fold: 4
# ROC_AUC: 0.6267525577870406
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7362637362637363, 0.52]
# Fold: 5
# ROC_AUC: 0.5893804471390679
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7994505494505495, 0.38]
# Fold: 6
# ROC_AUC: 0.5377510420613869
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.42032967032967034, 0.66]
# Fold: 7
# ROC_AUC: 0.6131110269041304
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.32967032967032966, 0.9]
# Fold: 8
# ROC_AUC: 0.684818968909878
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.5482093663911846, 0.82]
# Fold: 9
# ROC_AUC: 0.7137445887445888
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.6060606060606061, 0.82]
# Fold: 10
# ROC_AUC: 0.6249016135379771
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.928374655647383, 0.32]
# Mean: 0.6426127164371678
# Std deviation: 0.052561750404977854
# Wall time: 2min 51s

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Random OverSampler

# %%
sampler = RandomOverSampler(random_state=42)

# %% [markdown]
# ## Light GBM

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', lbm.LGBMClassifier())
    ])


clf = GridSearchCV(base_clf, param_lgm_grid, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Light GBM - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Light GBM - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6002273588480485
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8901098901098901, 0.31]
# Fold: 2
# ROC_AUC: 0.6348522167487685
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8214285714285714, 0.45]
# Fold: 3
# ROC_AUC: 0.5997536945812807
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.7857142857142857, 0.41]
# Fold: 4
# ROC_AUC: 0.5753599848427435
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9093406593406593, 0.24]
# Fold: 5
# ROC_AUC: 0.5825123152709359
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.7857142857142857, 0.38]
# Fold: 6
# ROC_AUC: 0.526525198938992
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8461538461538461, 0.21]
# Fold: 7
# ROC_AUC: 0.6186528988253126
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.6510989010989011, 0.59]
# Fold: 8
# ROC_AUC: 0.6248524203069659
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8925619834710744, 0.36]
# Fold: 9
# ROC_AUC: 0.6962809917355371
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8925619834710744, 0.5]
# Fold: 10
# ROC_AUC: 0.5094942935852027
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9118457300275482, 0.11]
# Mean: 0.5968511373683787
# Std deviation: 0.05084684607720441
# Wall time: 7.17 s

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Logistic Regression

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', LogisticRegression(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_lr_grid, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Logistic Regression - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Logistic Regression - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6458412277377794
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8434065934065934, 0.45]
# Fold: 2
# ROC_AUC: 0.7817828723001137
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.804945054945055, 0.76]
# Fold: 3
# ROC_AUC: 0.700454717696097
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7802197802197802, 0.62]
# Fold: 4
# ROC_AUC: 0.6905551345206519
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8983516483516484, 0.48]
# Fold: 5
# ROC_AUC: 0.5556555513452065
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7664835164835165, 0.34]
# Fold: 6
# ROC_AUC: 0.5895225464190982
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7307692307692307, 0.45]
# Fold: 7
# ROC_AUC: 0.734463812050019
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6758241758241759, 0.79]
# Fold: 8
# ROC_AUC: 0.7869441164895711
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8953168044077136, 0.68]
# Fold: 9
# ROC_AUC: 0.7538862652499017
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8292011019283747, 0.68]
# Fold: 10
# ROC_AUC: 0.6990850059031878
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9338842975206612, 0.46]
# Mean: 0.6938191249711625
# Std deviation: 0.07349910138404453
# Wall time: 39.3 s

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - Linear

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_linear, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM Linear - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM Linear - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6278419856006063
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8763736263736264, 0.38]
# Fold: 2
# ROC_AUC: 0.7741568776051534
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8241758241758241, 0.72]
# Fold: 3
# ROC_AUC: 0.7203012504736642
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8543956043956044, 0.59]
# Fold: 4
# ROC_AUC: 0.7194012883668056
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9560439560439561, 0.48]
# Fold: 5
# ROC_AUC: 0.4970159151193634
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.4423076923076923, 0.55]
# Fold: 6
# ROC_AUC: 0.5776335733232285
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8104395604395604, 0.34]
# Fold: 7
# ROC_AUC: 0.6964759378552482
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7032967032967034, 0.69]
# Fold: 8
# ROC_AUC: 0.7787288469106651
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9146005509641874, 0.64]
# Fold: 9
# ROC_AUC: 0.6592384887839433
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9256198347107438, 0.39]
# Fold: 10
# ROC_AUC: 0.6785222353404171
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9641873278236914, 0.39]
# Mean: 0.6729316399379096
# Std deviation: 0.08287167052046725
# Wall time: 11min 28s

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - RBF

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_rbf, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM RBF - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM RBF - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6305892383478591
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8818681318681318, 0.38]
# Fold: 2
# ROC_AUC: 0.7733990147783253
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8571428571428571, 0.69]
# Fold: 3
# ROC_AUC: 0.7271693823417962
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8681318681318682, 0.59]
# Fold: 4
# ROC_AUC: 0.7070386510041683
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9313186813186813, 0.48]
# Fold: 5
# ROC_AUC: 0.6211159530125048
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7939560439560439, 0.45]
# Fold: 6
# ROC_AUC: 0.6349943160287987
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7527472527472527, 0.52]
# Fold: 7
# ROC_AUC: 0.735079575596817
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7115384615384616, 0.76]
# Fold: 8
# ROC_AUC: 0.7636265249901613
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9201101928374655, 0.61]
# Fold: 9
# ROC_AUC: 0.7553128689492326
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8677685950413223, 0.64]
# Fold: 10
# ROC_AUC: 0.6345434868162141
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9476584022038568, 0.32]
# Mean: 0.6982869011865878
# Std deviation: 0.05833956786482631
# Wall time: 18min 4s

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Decision Tree

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', DecisionTreeClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_dtc_grid, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Decision Tree - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Decision Tree - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.0, 1.0]
# Fold: 2
# ROC_AUC: 0.7207275483137552
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.6483516483516484, 0.79]
# Fold: 3
# ROC_AUC: 0.6087533156498673
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.7692307692307693, 0.45]
# Fold: 4
# ROC_AUC: 0.6522356953391436
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.7527472527472527, 0.55]
# Fold: 5
# ROC_AUC: 0.618368700265252
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.7884615384615384, 0.45]
# Fold: 6
# ROC_AUC: 0.5
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.0, 1.0]
# Fold: 7
# ROC_AUC: 0.4868794998105343
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.008241758241758242, 0.97]
# Fold: 8
# ROC_AUC: 0.762150728059819
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8457300275482094, 0.68]
# Fold: 9
# ROC_AUC: 0.7495572609208973
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.6776859504132231, 0.82]
# Fold: 10
# ROC_AUC: 0.5320739866194412
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.349862258953168, 0.71]
# Mean: 0.613074673497871
# Std deviation: 0.1010339999031697
# Wall time: 1min 28s

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Random Forest

# %% [markdown]
# %%time
#
# base_clf = Pipeline([
#         ('sampling', sampler),
#         ('clf', RandomForestClassifier(random_state=42))
#     ])
#
# clf = GridSearchCV(base_clf, parameters_rfc_grid, cv=10, scoring='roc_auc', n_jobs=-1)
#
# scores_list = list()
#
# results_dict['Random Forest - RandomOverSampler'] = dict()
#
# for k, (train, test) in enumerate(k_fold.split(X, y)):
#     clf.fit(X.iloc[train], y.iloc[train])
#
#     print('Fold: ' + str(k + 1))
#
#     print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
#     print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
#     cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
#     cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
#     print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
#
#     results_dict['Random Forest - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),
#                                                              str(clf.get_params()['estimator']),
#                                                              '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
#
#     scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
#
# print('Mean: ' + str(np.mean(scores_list)))
# print('Std deviation: ' + str(np.std(scores_list)))

# %% [markdown]
# with open('partial_results_oversampling.pickle', 'wb') as handle:
#     pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## KNN

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', KNeighborsClassifier())
    ])

clf = GridSearchCV(base_clf, parameters_knn_grid, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['KNN - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['KNN - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6783345964380447
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.804945054945055, 0.55]
# Fold: 2
# ROC_AUC: 0.6854869268662371
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.6813186813186813, 0.69]
# Fold: 3
# ROC_AUC: 0.584785903751421
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.6868131868131868, 0.48]
# Fold: 4
# ROC_AUC: 0.6562144751799924
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8296703296703297, 0.48]
# Fold: 5
# ROC_AUC: 0.5972906403940886
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.6428571428571429, 0.55]
# Fold: 6
# ROC_AUC: 0.5872015915119363
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.5192307692307693, 0.66]
# Fold: 7
# ROC_AUC: 0.6238158393330807
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.489010989010989, 0.76]
# Fold: 8
# ROC_AUC: 0.7140397481306573
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8209366391184573, 0.61]
# Fold: 9
# ROC_AUC: 0.7083825265643447
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7024793388429752, 0.71]
# Fold: 10
# ROC_AUC: 0.6247540338449429
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8209366391184573, 0.43]
# Mean: 0.6460306282014746
# Std deviation: 0.04663754365803978
# Wall time: 1min 8s

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Adaboost

# %% [markdown]
# %%time
#
# adaboost_base = DecisionTreeClassifier(random_state = 42)
#
# base_clf = Pipeline([
#         ('sampling', sampler),
#         ('clf', AdaBoostClassifier(random_state=42, base_estimator=adaboost_base))
#     ])
#
# clf = GridSearchCV(base_clf, parameters_ABC_grid, cv=10, scoring='roc_auc', n_jobs=-1)
#
# scores_list = list()
#
# results_dict['Adaboost - RandomOverSampler'] = dict()
#
# for k, (train, test) in enumerate(k_fold.split(X, y)):
#     clf.fit(X.iloc[train], y.iloc[train])
#
#     print('Fold: ' + str(k + 1))
#
#     print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
#     print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
#     cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
#     cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
#     print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
#
#     results_dict['Adaboost - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),
#                                                              str(clf.get_params()['estimator']),
#                                                              '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
#
#     scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
#
# print('Mean: ' + str(np.mean(scores_list)))
# print('Std deviation: ' + str(np.std(scores_list)))

# %% [markdown]
# with open('partial_results_oversampling.pickle', 'wb') as handle:
#     pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Gradient Boost

# %% [markdown]
# %%time
#
# base_clf = Pipeline([
#         ('sampling', sampler),
#         ('clf', GradientBoostingClassifier(random_state=42))
#     ])
#
#
# clf = GridSearchCV(base_clf, parameters_GBC, cv=10, scoring='roc_auc', n_jobs=-1)
#
#
# scores_list = list()
#
# results_dict['Gradient Boost - RandomOverSampler'] = dict()
#
# for k, (train, test) in enumerate(k_fold.split(X, y)):
#     clf.fit(X.iloc[train], y.iloc[train])
#
#     print('Fold: ' + str(k + 1))
#
#     print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
#     print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
#     cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
#     cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
#     print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
#
#     results_dict['Gradient Boost - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])),
#                                                              str(clf.get_params()['estimator']),
#                                                              '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
#
#     scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
#
# print('Mean: ' + str(np.mean(scores_list)))
# print('Std deviation: ' + str(np.std(scores_list)))

# %% [markdown]
# with open('partial_results_oversampling.pickle', 'wb') as handle:
#     pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## XGBoost

# %%
# %%time


base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', xgb.XGBClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, param_xgb_grid, cv=10, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['XGBoost - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['XGBoost - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.629973474801061
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8461538461538461, 0.41]
# Fold: 2
# ROC_AUC: 0.7111121636983706
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.6291208791208791, 0.79]
# Fold: 3
# ROC_AUC: 0.6502463054187193
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7142857142857143, 0.59]
# Fold: 4
# ROC_AUC: 0.6522356953391436
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7527472527472527, 0.55]
# Fold: 5
# ROC_AUC: 0.6597195907540735
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8021978021978022, 0.52]
# Fold: 6
# ROC_AUC: 0.6644562334217506
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8461538461538461, 0.48]
# Fold: 7
# ROC_AUC: 0.700454717696097
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7802197802197802, 0.62]
# Fold: 8
# ROC_AUC: 0.7182703659976386
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9008264462809917, 0.54]
# Fold: 9
# ROC_AUC: 0.6987898465171193
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.71900826446281, 0.68]
# Fold: 10
# ROC_AUC: 0.7154171585989768
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8236914600550964, 0.61]
# Mean: 0.6800675552242951
# Std deviation: 0.030446784386091663
# Wall time: 2min 22s

# %%
with open('partial_results_oversampling.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
