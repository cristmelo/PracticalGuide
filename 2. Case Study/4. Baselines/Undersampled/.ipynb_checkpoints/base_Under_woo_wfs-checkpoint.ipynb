# %%
# %run auxiliary.ipynb

# %%
all_df = pd.read_csv('wo_outliers.csv') # Original data

# %%
results_dict = dict()

# %%
k_fold = StratifiedKFold(10, random_state=42)

X_features = ['CBO','CC','LCOM','WMC']

X = pd.DataFrame(all_df.loc[:, X_features])

y = pd.DataFrame(all_df.loc[:, 'will_change'])

X = X.rename(columns={'CBO':'f0', 'CC':'f1', 'LCOM':'f2', 'WMC':'f3'})

# %%
parameters_svc_linear = {
        'kernel':['linear'],
    'max_iter':[10000],
    }

parameters_svc_rbf = {
        'kernel':['rbf'],
    }

parameters_dtc_grid = {
    'criterion':['gini'], 
    }

parameters_rfc_grid = { 
    'criterion' :['gini'],
}

parameters_ABC_grid = { 
    'n_estimators':  [50],
}


parameters_knn_grid = {'n_neighbors': [5]}

parameters_lr_grid = [{ 
                        'penalty':['l2'],
                        }]

parameters_GBC = {
    "loss":["deviance"],
    }


param_xgb_grid = {
           'random_state': [42] #ensemble xgboost with multiple seeds may reduce variance
             }

param_lgm_grid = {
    "random_state":[42]
}

# %% [markdown]
# # Random UnderSampler

# %% [markdown]
# ## Light GBM

# %%
# %%time

base_clf = lbm.LGBMClassifier()


clf = GridSearchCV(base_clf, param_lgm_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Light GBM - RandomUnderSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = RandomUnderSampler(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Light GBM - RandomUnderSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.6694770746494885
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.7527472527472527, 0.59]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.6966180371352785
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.6346153846153846, 0.76]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.6758715422508526
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.6620879120879121, 0.69]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.7094543387646836
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.7637362637362637, 0.66]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.6566407730200834
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.6236263736263736, 0.69]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.649014778325123
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.6428571428571429, 0.66]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.5872015915119363
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.5192307692307693, 0.66]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.7264364423455333
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.8457300275482094, 0.61]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.7482290436835892
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.7107438016528925, 0.79]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.617965367965368
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.8787878787878788, 0.36]
# Mean: 0.6736908989651936
# Std deviation: 0.04653017194203846
# Wall time: 5.49 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Logistic Regression

# %%
# %%time

base_clf = LogisticRegression(random_state=42)

clf = GridSearchCV(base_clf, parameters_lr_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Logistic Regression - Random UnderSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = RandomUnderSampler(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Logistic Regression - Random UnderSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.7071807502841986
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.8626373626373627, 0.55]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.6996968548692687
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.8131868131868132, 0.59]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.7190697233800682
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.782967032967033, 0.66]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5503031451307313
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.6868131868131868, 0.41]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.6044903372489578
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.8296703296703297, 0.38]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.6131583933308071
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.6401098901098901, 0.59]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.7268378173550587
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.695054945054945, 0.76]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.5900728059818969
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.5730027548209367, 0.61]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.7057260920897284
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.768595041322314, 0.64]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.6123081463990555
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.7603305785123967, 0.46]
# Mean: 0.652884406606977
# Std deviation: 0.06149482290629206
# Wall time: 515 ms

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - Linear

# %%
# %%time

base_clf = svm.SVC(random_state=42)

clf = GridSearchCV(base_clf, parameters_svc_linear, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM Linear - Random UnderSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = RandomUnderSampler(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM Linear - Random UnderSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.7291587722622206
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.9065934065934066, 0.55]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.6775767336112164
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.8379120879120879, 0.52]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.6948181129215613
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.8379120879120879, 0.55]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5358090185676393
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.6923076923076923, 0.38]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.583743842364532
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.8571428571428571, 0.31]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.6151477832512315
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.6785714285714286, 0.55]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.7143330807123911
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.739010989010989, 0.69]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.6024695001967729
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.5977961432506887, 0.61]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.6659779614325069
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.8319559228650137, 0.5]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5793486816214088
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.7658402203856749, 0.39]
# Mean: 0.6398383486941481
# Std deviation: 0.06188020082306366
# Wall time: 502 ms

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - RBF

# %%
# %%time

base_clf = svm.SVC(random_state=42)

clf = GridSearchCV(base_clf, parameters_svc_rbf, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM RBF - Random UnderSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = RandomUnderSampler(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM RBF - Random UnderSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.7305323986358468
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.9093406593406593, 0.55]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.6458412277377794
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.8434065934065934, 0.45]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.6775767336112164
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.8379120879120879, 0.52]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5226885183781735
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.7005494505494505, 0.34]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5747442212959455
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.8736263736263736, 0.28]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.6034009094353923
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.6895604395604396, 0.52]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.7053334596438045
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.7554945054945055, 0.66]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.5667552144824871
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.5977961432506887, 0.54]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.6508264462809918
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.8016528925619835, 0.5]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5243998425816607
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.7630853994490359, 0.29]
# Mean: 0.6202098972083299
# Std deviation: 0.0694258064854678
# Wall time: 667 ms

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Decision Tree

# %%
# %%time

base_clf = DecisionTreeClassifier(random_state=42)

clf = GridSearchCV(base_clf, parameters_dtc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Decision Tree - Random UnderSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = RandomUnderSampler(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Decision Tree - Random UnderSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.6647404319818112
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.7087912087912088, 0.62]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.66564039408867
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.6071428571428571, 0.72]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.6117847669571808
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.6373626373626373, 0.59]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.7529367184539599
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.7472527472527473, 0.76]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5800492610837438
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.6428571428571429, 0.52]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.537324744221296
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.6263736263736264, 0.45]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.5519609700644184
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.5521978021978022, 0.55]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.6837367178276269
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.7603305785123967, 0.61]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.6987406532861079
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.6831955922865014, 0.71]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.6330184966548603
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.837465564738292, 0.43]
# Mean: 0.6379933154619675
# Std deviation: 0.06486858173856032
# Wall time: 361 ms

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Random Forest

# %%
# %%time

base_clf = RandomForestClassifier(random_state=42)

clf = GridSearchCV(base_clf, parameters_rfc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Random Forest - Random UnderSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = RandomUnderSampler(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Random Forest - Random UnderSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.5904225085259568
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.6291208791208791, 0.55]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.6795187571049641
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.5659340659340659, 0.79]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.5890488821523304
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.6263736263736264, 0.55]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.7123436907919666
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.7005494505494505, 0.72]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5518188707843881
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.6208791208791209, 0.48]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.6496305418719212
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.6785714285714286, 0.62]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.6065744600227359
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.489010989010989, 0.72]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.6989374262101535
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.8264462809917356, 0.57]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.6932310114128297
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.6721763085399449, 0.71]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5822018890200708
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.8429752066115702, 0.32]
# Mean: 0.6353728037897317
# Std deviation: 0.05501716496698537
# Wall time: 2.1 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## KNN

# %%
# %%time

base_clf = KNeighborsClassifier()

clf = GridSearchCV(base_clf, parameters_knn_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['KNN - Random UnderSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = RandomUnderSampler(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['KNN - Random UnderSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.6633668056081848
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.7060439560439561, 0.62]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.7193539219401288
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.6456043956043956, 0.79]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.5959170140204623
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.6401098901098901, 0.55]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.6679613489958317
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.8186813186813187, 0.52]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.6482569154982949
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.6758241758241759, 0.62]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.5861595301250474
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.6895604395604396, 0.48]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.6389257294429708
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.5192307692307693, 0.76]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.668732782369146
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.837465564738292, 0.5]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.6919027941755215
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.7052341597796143, 0.68]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.6755706414797324
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.8154269972451791, 0.54]
# Mean: 0.6556147483655321
# Std deviation: 0.03857831751809686
# Wall time: 455 ms

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Adaboost

# %%
# %%time

adaboost_base = DecisionTreeClassifier(random_state = 42)

base_clf = AdaBoostClassifier(random_state=42, base_estimator=adaboost_base)

clf = GridSearchCV(base_clf, parameters_ABC_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Adaboost - Random UnderSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = RandomUnderSampler(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Adaboost - Random UnderSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.6247631678666161
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.6978021978021978, 0.55]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.6801345206517622
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.6016483516483516, 0.76]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.5615763546798029
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.5714285714285714, 0.55]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.652377794619174
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.6840659340659341, 0.62]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5525767336112164
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.5879120879120879, 0.52]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.559302766199318
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.6703296703296703, 0.45]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.5563660477453581
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.4230769230769231, 0.69]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.7332251082251082
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.7878787878787878, 0.68]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.660271546635183
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.6776859504132231, 0.64]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5204151908697363
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.8622589531680441, 0.18]
# Mean: 0.6101009231103275
# Std deviation: 0.06615040646737531
# Wall time: 2.45 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Gradient Boost

# %%
# %%time

base_clf = GradientBoostingClassifier(random_state=42)

clf = GridSearchCV(base_clf, parameters_GBC, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Gradient Boost - Random UnderSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = RandomUnderSampler(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Gradient Boost - Random UnderSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.6681034482758621
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.75, 0.59]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.7317165593027662
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.6703296703296703, 0.79]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.6421466464569913
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.6291208791208791, 0.66]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.679092459264873
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.771978021978022, 0.59]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.6290261462675255
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.6373626373626373, 0.62]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.6737400530503979
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.6923076923076923, 0.66]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.6244316028798786
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.5247252747252747, 0.72]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.7924045651318379
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.8705234159779615, 0.71]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.7688902007083824
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.7520661157024794, 0.79]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5891873278236914
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.928374655647383, 0.25]
# Mean: 0.6798739009162207
# Std deviation: 0.06225611164761022
# Wall time: 1.65 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## XGBoost

# %%
# %%time

base_clf = xgb.XGBClassifier(random_state=42)

clf = GridSearchCV(base_clf, param_xgb_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['XGBoost - Random UnderSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = RandomUnderSampler(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])
    
    X_resampled = X_resampled.rename(columns={'CBO':'f0', 'CC':'f1', 'LCOM':'f2', 'WMC':'f3'})

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['XGBoost - Random UnderSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.6465990905646078
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.8104395604395604, 0.48]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.713101553618795
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.6675824175824175, 0.76]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.6420045471769609
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.6978021978021978, 0.59]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.711443728685108
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.8021978021978022, 0.62]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.6255210306934446
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.6648351648351648, 0.59]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.6461254262978401
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.7060439560439561, 0.59]
# 1    258
# 0    258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.6071902235695339
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.5247252747252747, 0.69]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.7566902794175522
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.8705234159779615, 0.64]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.7840417158598977
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.7823691460055097, 0.79]
# 1    259
# 0    259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.6455135773317592
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.9338842975206612, 0.36]
# Mean: 0.67782311732155
# Std deviation: 0.056487527170793146
# Wall time: 1.11 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Edited Nearest Neighbour

# %% [markdown]
# ## Light GBM

# %%
# %%time

base_clf = lbm.LGBMClassifier()


clf = GridSearchCV(base_clf, param_lgm_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Light GBM - Edited Nearest Neighbour'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = EditedNearestNeighbours(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Light GBM - Edited Nearest Neighbour'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.6586775293671845
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.9725274725274725, 0.34]
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.699412656309208
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.9505494505494505, 0.45]
# 0    2927
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.6049640015157257
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.9340659340659341, 0.28]
# 0    2919
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5924592648730579
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.978021978021978, 0.21]
# 0    2937
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5712391057218644
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.9010989010989011, 0.24]
# 0    2950
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.534009094353922
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.8956043956043956, 0.17]
# 0    2942
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.675587343690792
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.7994505494505495, 0.55]
# 0    2935
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.7060212514757971
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.9834710743801653, 0.43]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.6592876820149548
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.9614325068870524, 0.36]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5095926800472256
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.9834710743801653, 0.04]
# Mean: 0.6211250609369732
# Std deviation: 0.06539816846565775
# Wall time: 2.85 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Logistic Regression

# %%
# %%time

base_clf = LogisticRegression(random_state=42)

clf = GridSearchCV(base_clf, parameters_lr_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Logistic Regression - Edited Nearest Neighbour'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = EditedNearestNeighbours(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Logistic Regression - Edited Nearest Neighbour'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.5517241379310345
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.1]
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.5517241379310345
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.1]
# 0    2927
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.5172413793103449
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.03]
# 0    2919
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5158677529367185
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9972527472527473, 0.03]
# 0    2937
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5344827586206896
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.07]
# 0    2950
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.5172413793103449
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.03]
# 0    2942
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.5344827586206896
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.07]
# 0    2935
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.5357142857142857
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.07]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.5700511609602518
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9972451790633609, 0.14]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5535714285714286
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.11]
# Mean: 0.5382101179906822
# Std deviation: 0.017400150069570606
# Wall time: 731 ms

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - Linear

# %%
# %%time

base_clf = svm.SVC(random_state=42)

clf = GridSearchCV(base_clf, parameters_svc_linear, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM Linear - Edited Nearest Neighbour'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = EditedNearestNeighbours(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM Linear - Edited Nearest Neighbour'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.5172413793103449
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.03]
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    2927
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    2919
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.49862637362637363
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.9972527472527473, 0.0]
# 0    2937
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5172413793103449
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.03]
# 0    2950
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.5172413793103449
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.03]
# 0    2942
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.5172413793103449
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.03]
# 0    2935
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.5343368752459662
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.9972451790633609, 0.07]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5357142857142857
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.07]
# Mean: 0.5137643051828005
# Std deviation: 0.013232224777387452
# Wall time: 1.37 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - RBF

# %%
# %%time

base_clf = svm.SVC(random_state=42)

clf = GridSearchCV(base_clf, parameters_svc_rbf, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM RBF - Edited Nearest Neighbour'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = EditedNearestNeighbours(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM RBF - Edited Nearest Neighbour'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    2927
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    2919
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    2937
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    2950
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.5172413793103449
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.03]
# 0    2942
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    2935
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.5164797323888233
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [0.9972451790633609, 0.04]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5357142857142857
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.07]
# Mean: 0.5069435397413454
# Std deviation: 0.011671458789781264
# Wall time: 2.06 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Decision Tree

# %%
# %%time

base_clf = DecisionTreeClassifier(random_state=42)

clf = GridSearchCV(base_clf, parameters_dtc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Decision Tree - Edited Nearest Neighbour'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = EditedNearestNeighbours(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Decision Tree - Edited Nearest Neighbour'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.6408203865100417
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.9368131868131868, 0.34]
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.6809397499052672
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.8791208791208791, 0.48]
# 0    2927
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.5575028419856006
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.8736263736263736, 0.24]
# 0    2919
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5732284956422887
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.9395604395604396, 0.21]
# 0    2937
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5555134520651763
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.8351648351648352, 0.28]
# 0    2950
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.548503220917014
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.8901098901098901, 0.21]
# 0    2942
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.6165214096248579
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.6813186813186813, 0.55]
# 0    2935
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.6482683982683983
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.9393939393939394, 0.36]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.6344942935852027
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.9118457300275482, 0.36]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.527400629673357
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.9476584022038568, 0.11]
# Mean: 0.5983192878177205
# Std deviation: 0.04940274519930148
# Wall time: 707 ms

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Random Forest

# %%
# %%time

base_clf = RandomForestClassifier(random_state=42)

clf = GridSearchCV(base_clf, parameters_rfc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Random Forest - Edited Nearest Neighbour'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = EditedNearestNeighbours(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Random Forest - Edited Nearest Neighbour'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.6345680181887079
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9587912087912088, 0.31]
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.6739295187571049
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9340659340659341, 0.41]
# 0    2927
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.6098427434634331
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9093406593406593, 0.31]
# 0    2919
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.6014588859416445
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9615384615384616, 0.24]
# 0    2937
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5539977264115195
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9010989010989011, 0.21]
# 0    2950
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.5381299734748011
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9038461538461539, 0.17]
# 0    2942
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.6371258052292534
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.7225274725274725, 0.55]
# 0    2935
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.6826544667453758
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9724517906336089, 0.39]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.6428079496261314
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9641873278236914, 0.32]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5260724124360487
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9807162534435262, 0.07]
# Mean: 0.6100587500274021
# Std deviation: 0.052153379036963904
# Wall time: 2.45 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## KNN

# %%
# %%time

base_clf = KNeighborsClassifier()

clf = GridSearchCV(base_clf, parameters_knn_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['KNN - Edited Nearest Neighbour'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = EditedNearestNeighbours(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['KNN - Edited Nearest Neighbour'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.5938328912466844
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.9807692307692307, 0.21]
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.5869647593785525
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.967032967032967, 0.21]
# 0    2927
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.5863489958317545
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.9313186813186813, 0.24]
# 0    2919
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5634710117468739
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.989010989010989, 0.14]
# 0    2937
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5628552482000758
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.9532967032967034, 0.17]
# 0    2950
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.49739484653277755
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.9258241758241759, 0.07]
# 0    2942
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.7077965138309966
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.8983516483516484, 0.52]
# 0    2935
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.708776072412436
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.9889807162534435, 0.43]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.6084710743801652
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.9669421487603306, 0.25]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.6002558048012593
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.9862258953168044, 0.21]
# Mean: 0.6016167218361577
# Std deviation: 0.06093785908302843
# Wall time: 1.06 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Adaboost

# %%
# %%time

adaboost_base = DecisionTreeClassifier(random_state = 42)

base_clf = AdaBoostClassifier(random_state=42, base_estimator=adaboost_base)

clf = GridSearchCV(base_clf, parameters_ABC_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Adaboost - Edited Nearest Neighbour'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = EditedNearestNeighbours(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Adaboost - Edited Nearest Neighbour'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.6408203865100417
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.9368131868131868, 0.34]
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.6429518757104964
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.9065934065934066, 0.38]
# 0    2927
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.5802387267904509
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.8846153846153846, 0.28]
# 0    2919
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5718548692686624
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.9368131868131868, 0.21]
# 0    2937
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5761178476695719
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.8763736263736264, 0.28]
# 0    2950
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.534009094353922
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.8956043956043956, 0.17]
# 0    2942
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.6606195528609321
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.7005494505494505, 0.62]
# 0    2935
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.6798996458087366
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.9669421487603306, 0.39]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.6317886658795749
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.9421487603305785, 0.32]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5205627705627706
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.9696969696969697, 0.07]
# Mean: 0.603886343541516
# Std deviation: 0.05181449636907549
# Wall time: 4.1 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Gradient Boost

# %%
# %%time

base_clf = GradientBoostingClassifier(random_state=42)

clf = GridSearchCV(base_clf, parameters_GBC, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Gradient Boost - Edited Nearest Neighbour'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = EditedNearestNeighbours(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Gradient Boost - Edited Nearest Neighbour'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.6455570291777188
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9807692307692307, 0.31]
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.6835449033724895
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9532967032967034, 0.41]
# 0    2927
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.6276998863205759
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.945054945054945, 0.31]
# 0    2919
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5993273967411898
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9917582417582418, 0.21]
# 0    2937
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5987116331943918
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9560439560439561, 0.24]
# 0    2950
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.5146362258431224
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9258241758241759, 0.1]
# 0    2942
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.7222906403940886
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.8928571428571429, 0.55]
# 0    2935
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.6881641086186541
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9834710743801653, 0.39]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.6812770562770563
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9696969696969697, 0.39]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5535714285714286
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.11]
# Mean: 0.6314780308510716
# Std deviation: 0.06220320116162562
# Wall time: 3.01 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## XGBoost

# %%
# %%time

base_clf = xgb.XGBClassifier(random_state=42)

clf = GridSearchCV(base_clf, param_xgb_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['XGBoost - Edited Nearest Neighbour'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = EditedNearestNeighbours(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    X_resampled = X_resampled.rename(columns={'CBO':'f0', 'CC':'f1', 'LCOM':'f2', 'WMC':'f3'})
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['XGBoost - Edited Nearest Neighbour'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.6414361500568396
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.9725274725274725, 0.31]
# 0    2922
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.6586775293671845
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.9725274725274725, 0.34]
# 0    2927
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.6187002652519894
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.9615384615384616, 0.28]
# 0    2919
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.6179424024251611
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.9945054945054945, 0.24]
# 0    2937
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.6000852595680183
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.9587912087912088, 0.24]
# 0    2950
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.5532398635846912
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.9340659340659341, 0.17]
# 0    2942
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.7174118984463811
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.9175824175824175, 0.52]
# 0    2935
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.6716843762298308
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.9862258953168044, 0.36]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.664797323888233
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.9724517906336089, 0.36]
# 0    2947
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5178571428571429
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [1.0, 0.04]
# Mean: 0.6261832211675472
# Std deviation: 0.0557071714270684
# Wall time: 3.47 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Tomek Links

# %% [markdown]
# ## Light GBM

# %%
# %%time

base_clf = lbm.LGBMClassifier()


clf = GridSearchCV(base_clf, param_lgm_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Light GBM - Tomek Links'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = TomekLinks(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Light GBM - Tomek Links'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.6193160287987874
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.9972527472527473, 0.24]
# 0    3250
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.6310629026146268
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.9862637362637363, 0.28]
# 0    3251
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.5952065176203106
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.9835164835164835, 0.21]
# 0    3249
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5662182644941266
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.9945054945054945, 0.14]
# 0    3245
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5566028798787419
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.9752747252747253, 0.14]
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.5035051155740812
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.9725274725274725, 0.03]
# 0    3225
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.6691928760894278
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.8901098901098901, 0.45]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.6744391971664699
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.9917355371900827, 0.36]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.5988783943329398
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [0.9834710743801653, 0.21]
# 0    3255
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5178571428571429
# Estimator and parameters: LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# [Confusion Matrix]: [1.0, 0.04]
# Mean: 0.5932279319426655
# Std deviation: 0.05505970837840761
# Wall time: 3.14 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Logistic Regression

# %%
# %%time

base_clf = LogisticRegression(random_state=42)

clf = GridSearchCV(base_clf, parameters_lr_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Logistic Regression - Tomek Links'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = TomekLinks(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Logistic Regression - Tomek Links'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.5344827586206896
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.07]
# 0    3250
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.5517241379310345
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.1]
# 0    3251
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.5
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3249
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5158677529367185
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9972527472527473, 0.03]
# 0    3245
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5344827586206896
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.07]
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.5172413793103449
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.03]
# 0    3225
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.5344827586206896
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.07]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.5357142857142857
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.07]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.5700511609602518
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9972451790633609, 0.14]
# 0    3255
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5535714285714286
# Estimator and parameters: LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.11]
# Mean: 0.5347618421286133
# Std deviation: 0.019391585154826616
# Wall time: 776 ms

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - Linear

# %%
# %%time

base_clf = svm.SVC(random_state=42)

clf = GridSearchCV(base_clf, parameters_svc_linear, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM Linear - Tomek Links'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = TomekLinks(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM Linear - Tomek Links'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3250
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3251
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3249
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3245
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3225
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3255
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# Mean: 0.5
# Std deviation: 0.0
# Wall time: 1.54 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - RBF

# %%
# %%time

base_clf = svm.SVC(random_state=42)

clf = GridSearchCV(base_clf, parameters_svc_rbf, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM RBF - Tomek Links'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = TomekLinks(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM RBF - Tomek Links'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3250
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3251
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3249
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3245
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3225
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# 0    3255
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5
# Estimator and parameters: SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False)
# [Confusion Matrix]: [1.0, 0.0]
# Mean: 0.5
# Std deviation: 0.0
# Wall time: 2.3 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Decision Tree

# %%
# %%time

base_clf = DecisionTreeClassifier(random_state=42)

clf = GridSearchCV(base_clf, parameters_dtc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Decision Tree - Tomek Links'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = TomekLinks(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Decision Tree - Tomek Links'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.613821523304282
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.9862637362637363, 0.24]
# 0    3250
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.6469306555513451
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.9835164835164835, 0.31]
# 0    3251
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.5765915119363396
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.9807692307692307, 0.17]
# 0    3249
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5511083743842365
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.9642857142857143, 0.14]
# 0    3245
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5587343690791967
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.945054945054945, 0.17]
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.4987684729064039
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.9285714285714286, 0.07]
# 0    3225
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.6334785903751421
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.8186813186813187, 0.45]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.6758166076347895
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.9944903581267218, 0.36]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.6221959858323495
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.9586776859504132, 0.29]
# 0    3255
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5508166076347895
# Estimator and parameters: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')
# [Confusion Matrix]: [0.9944903581267218, 0.11]
# Mean: 0.5928262698638875
# Std deviation: 0.05152529623051025
# Wall time: 673 ms

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Random Forest

# %%
# %%time

base_clf = RandomForestClassifier(random_state=42)

clf = GridSearchCV(base_clf, parameters_rfc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Random Forest - Tomek Links'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = TomekLinks(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Random Forest - Tomek Links'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.613821523304282
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9862637362637363, 0.24]
# 0    3250
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.6310629026146268
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9862637362637363, 0.28]
# 0    3251
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.5710970064418341
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9697802197802198, 0.17]
# 0    3249
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5738442591890868
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9752747252747253, 0.17]
# 0    3245
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5765915119363396
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9807692307692307, 0.17]
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.499384236453202
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9642857142857143, 0.03]
# 0    3225
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.6176108374384236
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.8214285714285714, 0.41]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.6579594647776466
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9944903581267218, 0.32]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.6030106257378984
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9917355371900827, 0.21]
# 0    3255
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.49724517906336085
# Estimator and parameters: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9944903581267218, 0.0]
# Mean: 0.5841627546956701
# Std deviation: 0.05007575090218064
# Wall time: 2.53 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## KNN

# %%
# %%time

base_clf = KNeighborsClassifier()

clf = GridSearchCV(base_clf, parameters_knn_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['KNN - Tomek Links'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = TomekLinks(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['KNN - Tomek Links'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.5303618794998105
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.9917582417582418, 0.07]
# 0    3250
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.5517241379310345
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [1.0, 0.1]
# 0    3251
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.5648446381205002
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.9917582417582418, 0.14]
# 0    3249
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5158677529367185
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.9972527472527473, 0.03]
# 0    3245
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5317355058734369
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.9945054945054945, 0.07]
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.5035051155740812
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.9725274725274725, 0.03]
# 0    3225
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.7007862826828344
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.9532967032967034, 0.45]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.6428571428571428
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [1.0, 0.29]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.5961235733963006
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [0.977961432506887, 0.21]
# 0    3255
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5892857142857143
# Estimator and parameters: KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
# [Confusion Matrix]: [1.0, 0.18]
# Mean: 0.5727091743157574
# Std deviation: 0.058431160724419236
# Wall time: 1.18 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Adaboost

# %%
# %%time

adaboost_base = DecisionTreeClassifier(random_state = 42)

base_clf = AdaBoostClassifier(random_state=42, base_estimator=adaboost_base)

clf = GridSearchCV(base_clf, parameters_ABC_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Adaboost - Tomek Links'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = TomekLinks(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Adaboost - Tomek Links'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.5979537703675635
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.989010989010989, 0.21]
# 0    3250
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.6455570291777188
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.9807692307692307, 0.31]
# 0    3251
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.585591133004926
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.9642857142857143, 0.21]
# 0    3249
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5710970064418341
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.9697802197802198, 0.17]
# 0    3245
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5683497536945813
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.9642857142857143, 0.17]
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.5166256157635468
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.9642857142857143, 0.07]
# 0    3225
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.6383573323228496
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.7939560439560439, 0.48]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.6758166076347895
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.9944903581267218, 0.36]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.594746162927981
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.9752066115702479, 0.21]
# 0    3255
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5151023219205038
# Estimator and parameters: AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42)
# [Confusion Matrix]: [0.9944903581267218, 0.04]
# Mean: 0.5909196733256294
# Std deviation: 0.049704921933571206
# Wall time: 4.88 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Gradient Boost

# %%
# %%time

base_clf = GradientBoostingClassifier(random_state=42)

clf = GridSearchCV(base_clf, parameters_GBC, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Gradient Boost - Tomek Links'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = TomekLinks(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Gradient Boost - Tomek Links'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.6551724137931034
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.31]
# 0    3250
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.6007010231148162
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9945054945054945, 0.21]
# 0    3251
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.5807123910572187
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.989010989010989, 0.17]
# 0    3249
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5834596438044715
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9945054945054945, 0.17]
# 0    3245
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5820860174308451
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9917582417582418, 0.17]
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.5007578628268283
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.967032967032967, 0.03]
# 0    3225
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.6980390299355816
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9478021978021978, 0.45]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.6579594647776466
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9944903581267218, 0.32]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.6030106257378984
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [0.9917355371900827, 0.21]
# 0    3255
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5178571428571429
# Estimator and parameters: GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=42,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
# [Confusion Matrix]: [1.0, 0.04]
# Mean: 0.5979755615335554
# Std deviation: 0.057919318681298904
# Wall time: 3.33 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## XGBoost

# %%
# %%time

base_clf = xgb.XGBClassifier(random_state=42)

clf = GridSearchCV(base_clf, param_xgb_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['XGBoost - Tomek Links'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    X_resampled, y_resampled = TomekLinks(random_state=42).fit_sample(X.iloc[train], y.iloc[train])
    X_resampled = pd.DataFrame(X_resampled, columns=X_features)
    y_resampled = pd.DataFrame(y_resampled, columns=['will_change'])

    print(y_resampled['will_change'].value_counts())
    
    X_resampled = X_resampled.rename(columns={'CBO':'f0', 'CC':'f1', 'LCOM':'f2', 'WMC':'f3'})
    
    clf.fit(X_resampled, y_resampled)
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['XGBoost - Tomek Links'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 1
# ROC_AUC: 0.6379310344827587
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [1.0, 0.28]
# 0    3250
# 1     258
# Name: will_change, dtype: int64
# Fold: 2
# ROC_AUC: 0.6007010231148162
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.9945054945054945, 0.21]
# 0    3251
# 1     258
# Name: will_change, dtype: int64
# Fold: 3
# ROC_AUC: 0.5820860174308451
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.9917582417582418, 0.17]
# 0    3249
# 1     258
# Name: will_change, dtype: int64
# Fold: 4
# ROC_AUC: 0.5503505115574081
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.9972527472527473, 0.1]
# 0    3245
# 1     258
# Name: will_change, dtype: int64
# Fold: 5
# ROC_AUC: 0.5820860174308451
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.9917582417582418, 0.17]
# 0    3246
# 1     258
# Name: will_change, dtype: int64
# Fold: 6
# ROC_AUC: 0.5007578628268283
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.967032967032967, 0.03]
# 0    3225
# 1     258
# Name: will_change, dtype: int64
# Fold: 7
# ROC_AUC: 0.6876657824933687
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.9615384615384616, 0.41]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 8
# ROC_AUC: 0.6414797323888232
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.9972451790633609, 0.29]
# 0    3249
# 1     259
# Name: will_change, dtype: int64
# Fold: 9
# ROC_AUC: 0.5851534828807556
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [0.9917355371900827, 0.18]
# 0    3255
# 1     259
# Name: will_change, dtype: int64
# Fold: 10
# ROC_AUC: 0.5
# Estimator and parameters: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        random_state=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1)
# [Confusion Matrix]: [1.0, 0.0]
# Mean: 0.586821146460645
# Std deviation: 0.056819543055451185
# Wall time: 3.81 s

# %%
with open('base_Under_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
