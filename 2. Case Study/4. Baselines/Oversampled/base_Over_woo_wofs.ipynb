# %%
# %run auxiliary.ipynb

# %%
all_df = pd.read_csv('wo_outliers.csv') # Original dataa

# %%
results_dict = dict()

# %%
k_fold = StratifiedKFold(10, random_state=42)

X_features = ['CBO','CC','DIT','LCOM','LOC','NOC','RFC','WMC']

X = pd.DataFrame(all_df.loc[:, X_features])

y = pd.DataFrame(all_df.loc[:, 'will_change'])
X = X.rename(columns={'CBO':'f0', 'CC':'f1', 'DIT':'f2', 'LCOM':'f3', 'LOC':'f4', 'NOC':'f5', 'RFC':'f6', 'WMC':'f7'})

# %%
X.head()
# Out:
#          f0        f1        f2   f3        f4   f5        f6        f7
# 0  0.000000  0.004098  0.000000  0.0  0.153397  0.0  0.000000  0.017857
# 1  0.000000  0.004098  0.000000  0.0  0.001461  0.0  0.000000  0.017857
# 2  0.129630  0.018443  0.000000  0.0  0.024105  0.0  0.043584  0.071429
# 3  0.006173  0.014344  0.285714  0.0  0.008035  0.0  0.004843  0.035714
# 4  0.006173  0.004098  0.000000  0.0  0.002191  0.0  0.002421  0.017857

# %%
parameters_svc_linear = {
        'clf__kernel':['linear'],
    'clf__max_iter':[10000],
    }

parameters_svc_rbf = {
        'clf__kernel':['rbf'],
    }

parameters_dtc_grid = {
    'clf__criterion':['gini'], 
}

parameters_rfc_grid = { 
    'clf__criterion' :['gini'],
}

parameters_ABC_grid = {
    'clf__base_estimator__criterion' : ["gini"],
}


parameters_knn_grid = {'clf__n_neighbors': [5]}


parameters_lr_grid = [{
                        'clf__penalty':['l2'],
                        }]

parameters_GBC = {
    "clf__loss":["deviance"],
    }


param_xgb_grid = {
           'clf__clf__random_state': [42] #ensemble xgboost with multiple seeds may reduce variance
             }

param_lgm_grid = {
    "clf__random_state":[42]
}

# %% [markdown]
# # SMOTE

# %%
sampler = SMOTE(random_state=42)

# %% [markdown]
# ## Light GBM

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', lbm.LGBMClassifier())
    ])


clf = GridSearchCV(base_clf, param_lgm_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Light GBM - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Light GBM - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6469306555513451
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9835164835164835, 0.31]
# Fold: 2
# ROC_AUC: 0.7035335354300871
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9587912087912088, 0.45]
# Fold: 3
# ROC_AUC: 0.6104585070102312
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.945054945054945, 0.28]
# Fold: 4
# ROC_AUC: 0.5924592648730579
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.978021978021978, 0.21]
# Fold: 5
# ROC_AUC: 0.6359416445623343
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9615384615384616, 0.31]
# Fold: 6
# ROC_AUC: 0.5208885941644562
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9038461538461539, 0.14]
# Fold: 7
# ROC_AUC: 0.6810818491852975
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8104395604395604, 0.55]
# Fold: 8
# ROC_AUC: 0.6895415190869736
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9862258953168044, 0.39]
# Fold: 9
# ROC_AUC: 0.6634199134199135
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9696969696969697, 0.36]
# Fold: 10
# ROC_AUC: 0.5260724124360487
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9807162534435262, 0.07]
# Mean: 0.6270327895719745
# Std deviation: 0.061163669935583316
# Wall time: 10.1 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Logistic Regression

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', LogisticRegression(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_lr_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Logistic Regression - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Logistic Regression - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6554566123531641
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8626373626373627, 0.45]
# Fold: 2
# ROC_AUC: 0.7659151193633953
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8076923076923077, 0.72]
# Fold: 3
# ROC_AUC: 0.7273114816218265
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7994505494505495, 0.66]
# Fold: 4
# ROC_AUC: 0.7077965138309966
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8983516483516484, 0.52]
# Fold: 5
# ROC_AUC: 0.654225085259568
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7912087912087912, 0.52]
# Fold: 6
# ROC_AUC: 0.5750284198560061
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7362637362637363, 0.41]
# Fold: 7
# ROC_AUC: 0.7434634331186054
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6593406593406593, 0.83]
# Fold: 8
# ROC_AUC: 0.7649547422274695
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8870523415977961, 0.64]
# Fold: 9
# ROC_AUC: 0.712711530893349
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8539944903581267, 0.57]
# Fold: 10
# ROC_AUC: 0.7265840220385674
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.953168044077135, 0.5]
# Mean: 0.7033446960562948
# Std deviation: 0.05631471348397851
# Wall time: 1.16 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - Linear

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_linear, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM Linear - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM Linear - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6464569912845775
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8791208791208791, 0.41]
# Fold: 2
# ROC_AUC: 0.7961348995831754
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8681318681318682, 0.72]
# Fold: 3
# ROC_AUC: 0.737542629784009
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8543956043956044, 0.62]
# Fold: 4
# ROC_AUC: 0.6939181508147025
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9395604395604396, 0.45]
# Fold: 5
# ROC_AUC: 0.6217317165593027
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8296703296703297, 0.41]
# Fold: 6
# ROC_AUC: 0.5838859416445624
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7884615384615384, 0.38]
# Fold: 7
# ROC_AUC: 0.7674308450170519
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7417582417582418, 0.79]
# Fold: 8
# ROC_AUC: 0.7746458087367178
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9421487603305785, 0.61]
# Fold: 9
# ROC_AUC: 0.679801259346714
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8953168044077136, 0.46]
# Fold: 10
# ROC_AUC: 0.6840318772136954
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9752066115702479, 0.39]
# Mean: 0.6985580119984509
# Std deviation: 0.06627571333324571
# Wall time: 18.3 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - RBF

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_rbf, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM RBF - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM RBF - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6415782493368701
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9038461538461539, 0.38]
# Fold: 2
# ROC_AUC: 0.7444107616521409
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8681318681318682, 0.62]
# Fold: 3
# ROC_AUC: 0.7050492610837439
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8928571428571429, 0.52]
# Fold: 4
# ROC_AUC: 0.6843027661993181
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9203296703296703, 0.45]
# Fold: 5
# ROC_AUC: 0.6250947328533536
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8708791208791209, 0.38]
# Fold: 6
# ROC_AUC: 0.5886225843122396
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8324175824175825, 0.34]
# Fold: 7
# ROC_AUC: 0.7480579765062524
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.771978021978022, 0.72]
# Fold: 8
# ROC_AUC: 0.7236816214088941
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8402203856749312, 0.61]
# Fold: 9
# ROC_AUC: 0.7100550964187328
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9201101928374655, 0.5]
# Fold: 10
# ROC_AUC: 0.6688803620621803
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9449035812672176, 0.39]
# Mean: 0.6839733411833726
# Std deviation: 0.05004441013610091
# Wall time: 28 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Decision Tree

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', DecisionTreeClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_dtc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Decision Tree - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Decision Tree - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6104585070102312
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.945054945054945, 0.28]
# Fold: 2
# ROC_AUC: 0.6580617658203866
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9368131868131868, 0.38]
# Fold: 3
# ROC_AUC: 0.5959643804471391
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9505494505494505, 0.24]
# Fold: 4
# ROC_AUC: 0.5601079954528231
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9478021978021978, 0.17]
# Fold: 5
# ROC_AUC: 0.590611974232664
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8708791208791209, 0.31]
# Fold: 6
# ROC_AUC: 0.45893330807123905
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8489010989010989, 0.07]
# Fold: 7
# ROC_AUC: 0.6261367942402425
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.7005494505494505, 0.55]
# Fold: 8
# ROC_AUC: 0.6647481306572216
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9366391184573003, 0.39]
# Fold: 9
# ROC_AUC: 0.6661255411255411
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9393939393939394, 0.39]
# Fold: 10
# ROC_AUC: 0.5040338449429359
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9366391184573003, 0.07]
# Mean: 0.5935182242000424
# Std deviation: 0.06566091854192899
# Wall time: 1.21 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Random Forest

# %%
# %%time


base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', RandomForestClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_rfc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Random Forest - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Random Forest - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6518093974990528
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9587912087912088, 0.34]
# Fold: 2
# ROC_AUC: 0.5994694960212202
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9230769230769231, 0.28]
# Fold: 3
# ROC_AUC: 0.5898541114058357
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9038461538461539, 0.28]
# Fold: 4
# ROC_AUC: 0.5269988632057597
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9505494505494505, 0.1]
# Fold: 5
# ROC_AUC: 0.5767336112163698
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9120879120879121, 0.24]
# Fold: 6
# ROC_AUC: 0.513262599469496
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9230769230769231, 0.1]
# Fold: 7
# ROC_AUC: 0.6130162940507767
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7087912087912088, 0.52]
# Fold: 8
# ROC_AUC: 0.7005116096025187
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9724517906336089, 0.43]
# Fold: 9
# ROC_AUC: 0.6221959858323495
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9586776859504132, 0.29]
# Fold: 10
# ROC_AUC: 0.5054604486422669
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9752066115702479, 0.04]
# Mean: 0.5899312416945646
# Std deviation: 0.05905073989857114
# Wall time: 2.95 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## KNN

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', KNeighborsClassifier())
    ])

clf = GridSearchCV(base_clf, parameters_knn_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['KNN - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['KNN - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5845017051913604
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8241758241758241, 0.34]
# Fold: 2
# ROC_AUC: 0.6598616900341039
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7335164835164835, 0.59]
# Fold: 3
# ROC_AUC: 0.5762599469496021
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8076923076923077, 0.34]
# Fold: 4
# ROC_AUC: 0.5520083364910952
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8626373626373627, 0.24]
# Fold: 5
# ROC_AUC: 0.5536661614247822
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.728021978021978, 0.38]
# Fold: 6
# ROC_AUC: 0.46272262220538085
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.6840659340659341, 0.24]
# Fold: 7
# ROC_AUC: 0.540214096248579
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.5631868131868132, 0.52]
# Fold: 8
# ROC_AUC: 0.6894431326249509
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.9146005509641874, 0.46]
# Fold: 9
# ROC_AUC: 0.712711530893349
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8539944903581267, 0.57]
# Fold: 10
# ROC_AUC: 0.611176702085793
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.9366391184573003, 0.29]
# Mean: 0.5942565924148997
# Std deviation: 0.07194142119271278
# Wall time: 2.52 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Adaboost

# %%
# %%time

adaboost_base = DecisionTreeClassifier(random_state = 42)

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', AdaBoostClassifier(random_state=42, base_estimator=adaboost_base))
    ])

clf = GridSearchCV(base_clf, parameters_ABC_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Adaboost - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Adaboost - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6345680181887079
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9587912087912088, 0.31]
# Fold: 2
# ROC_AUC: 0.6470727548313755
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9148351648351648, 0.38]
# Fold: 3
# ROC_AUC: 0.5636131110269041
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9203296703296703, 0.21]
# Fold: 4
# ROC_AUC: 0.5469874952633574
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9560439560439561, 0.14]
# Fold: 5
# ROC_AUC: 0.5967222432739674
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9175824175824175, 0.28]
# Fold: 6
# ROC_AUC: 0.5036472148541113
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9038461538461539, 0.1]
# Fold: 7
# ROC_AUC: 0.6130162940507767
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.7087912087912088, 0.52]
# Fold: 8
# ROC_AUC: 0.6922471467926014
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9559228650137741, 0.43]
# Fold: 9
# ROC_AUC: 0.6730125934671389
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.953168044077135, 0.39]
# Fold: 10
# ROC_AUC: 0.5164305391578119
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9614325068870524, 0.07]
# Mean: 0.5987317410906753
# Std deviation: 0.06149576827462222
# Wall time: 28.1 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Gradient Boost

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', GradientBoostingClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_GBC, scoring='roc_auc', n_jobs=-1)


scores_list = list()

results_dict['Gradient Boost - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Gradient Boost - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6588196286472148
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9038461538461539, 0.41]
# Fold: 2
# ROC_AUC: 0.7961348995831754
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8681318681318682, 0.72]
# Fold: 3
# ROC_AUC: 0.6423361121636983
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8708791208791209, 0.41]
# Fold: 4
# ROC_AUC: 0.6952917771883289
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9423076923076923, 0.45]
# Fold: 5
# ROC_AUC: 0.6665877226222053
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8159340659340659, 0.52]
# Fold: 6
# ROC_AUC: 0.5233042819249716
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7362637362637363, 0.31]
# Fold: 7
# ROC_AUC: 0.6626089427813566
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.739010989010989, 0.59]
# Fold: 8
# ROC_AUC: 0.7595434868162141
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9476584022038568, 0.57]
# Fold: 9
# ROC_AUC: 0.7031680440771348
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.90633608815427, 0.5]
# Fold: 10
# ROC_AUC: 0.5480617866981504
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9889807162534435, 0.11]
# Mean: 0.6655856682502451
# Std deviation: 0.07925787225232245
# Wall time: 7.52 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## XGBoost

# %%
# %%time


base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', xgb.XGBClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, param_xgb_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['XGBoost - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['XGBoost - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6719401288366806
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8956043956043956, 0.45]
# Fold: 2
# ROC_AUC: 0.7892667677150434
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8543956043956044, 0.72]
# Fold: 3
# ROC_AUC: 0.6485884804850321
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8489010989010989, 0.45]
# Fold: 4
# ROC_AUC: 0.6739295187571049
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9340659340659341, 0.41]
# Fold: 5
# ROC_AUC: 0.6714664645699128
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7912087912087912, 0.55]
# Fold: 6
# ROC_AUC: 0.5336775293671845
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7225274725274725, 0.34]
# Fold: 7
# ROC_AUC: 0.6557408109132247
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7252747252747253, 0.59]
# Fold: 8
# ROC_AUC: 0.7347992916174734
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9338842975206612, 0.54]
# Fold: 9
# ROC_AUC: 0.7004132231404959
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9008264462809917, 0.5]
# Fold: 10
# ROC_AUC: 0.5617866981503344
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9807162534435262, 0.14]
# Mean: 0.6641608913552486
# Std deviation: 0.07069978104163838
# Wall time: 9.35 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # ADASYN

# %%
sampler = ADASYN(random_state=42)

# %% [markdown]
# ## Light GBM

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', lbm.LGBMClassifier())
    ])


clf = GridSearchCV(base_clf, param_lgm_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Light GBM - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Light GBM - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6324365289882532
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.989010989010989, 0.28]
# Fold: 2
# ROC_AUC: 0.7221485411140585
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9615384615384616, 0.48]
# Fold: 3
# ROC_AUC: 0.6408203865100417
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9368131868131868, 0.34]
# Fold: 4
# ROC_AUC: 0.5924592648730579
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.978021978021978, 0.21]
# Fold: 5
# ROC_AUC: 0.5959643804471391
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9505494505494505, 0.24]
# Fold: 6
# ROC_AUC: 0.5160098522167488
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9285714285714286, 0.1]
# Fold: 7
# ROC_AUC: 0.6769609700644184
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8021978021978022, 0.55]
# Fold: 8
# ROC_AUC: 0.7225009838646202
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9807162534435262, 0.46]
# Fold: 9
# ROC_AUC: 0.6455627705627706
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9696969696969697, 0.32]
# Fold: 10
# ROC_AUC: 0.5151023219205038
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9944903581267218, 0.04]
# Mean: 0.6259966000561612
# Std deviation: 0.06944135937675185
# Wall time: 6.6 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Logistic Regression

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', LogisticRegression(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_lr_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Logistic Regression - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Logistic Regression - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6534672224327397
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8241758241758241, 0.48]
# Fold: 2
# ROC_AUC: 0.7688044713906783
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7445054945054945, 0.79]
# Fold: 3
# ROC_AUC: 0.7067070860174308
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7582417582417582, 0.66]
# Fold: 4
# ROC_AUC: 0.6775767336112164
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8379120879120879, 0.52]
# Fold: 5
# ROC_AUC: 0.6598616900341039
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7335164835164835, 0.59]
# Fold: 6
# ROC_AUC: 0.5716654035619553
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.695054945054945, 0.45]
# Fold: 7
# ROC_AUC: 0.7338480485032208
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6401098901098901, 0.83]
# Fold: 8
# ROC_AUC: 0.7511314443132625
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8236914600550964, 0.68]
# Fold: 9
# ROC_AUC: 0.7222550177095631
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8016528925619835, 0.64]
# Fold: 10
# ROC_AUC: 0.7265348288075562
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9173553719008265, 0.54]
# Mean: 0.6971851946381726
# Std deviation: 0.055143686642790526
# Wall time: 1.25 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - Linear

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_linear, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM Linear - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM Linear - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.640962485790072
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8681318681318682, 0.41]
# Fold: 2
# ROC_AUC: 0.7741568776051534
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8241758241758241, 0.72]
# Fold: 3
# ROC_AUC: 0.7238063660477453
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8269230769230769, 0.62]
# Fold: 4
# ROC_AUC: 0.673313755210307
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8983516483516484, 0.45]
# Fold: 5
# ROC_AUC: 0.6121163319439181
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8104395604395604, 0.41]
# Fold: 6
# ROC_AUC: 0.5701496779082985
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.760989010989011, 0.38]
# Fold: 7
# ROC_AUC: 0.7482000757862827
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7032967032967034, 0.79]
# Fold: 8
# ROC_AUC: 0.7814344746162928
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8842975206611571, 0.68]
# Fold: 9
# ROC_AUC: 0.6893939393939393
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8787878787878788, 0.5]
# Fold: 10
# ROC_AUC: 0.7196969696969697
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9393939393939394, 0.5]
# Mean: 0.6933230953998979
# Std deviation: 0.06622513428615089
# Wall time: 16.9 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - RBF

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_rbf, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM RBF - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM RBF - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6546987495263358
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8956043956043956, 0.41]
# Fold: 2
# ROC_AUC: 0.7169382341796134
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8131868131868132, 0.62]
# Fold: 3
# ROC_AUC: 0.7355532398635847
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8159340659340659, 0.66]
# Fold: 4
# ROC_AUC: 0.6233895414929898
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.695054945054945, 0.55]
# Fold: 5
# ROC_AUC: 0.6327207275483138
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8516483516483516, 0.41]
# Fold: 6
# ROC_AUC: 0.6501042061386889
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.782967032967033, 0.52]
# Fold: 7
# ROC_AUC: 0.7054755589238347
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.6868131868131868, 0.72]
# Fold: 8
# ROC_AUC: 0.6189492325855963
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.5950413223140496, 0.64]
# Fold: 9
# ROC_AUC: 0.7319460842188115
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8567493112947658, 0.61]
# Fold: 10
# ROC_AUC: 0.6288370720188903
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7933884297520661, 0.46]
# Mean: 0.6698612646496659
# Std deviation: 0.04482062316647222
# Wall time: 28 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Decision Tree

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', DecisionTreeClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_dtc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Decision Tree - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Decision Tree - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6090848806366048
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9423076923076923, 0.28]
# Fold: 2
# ROC_AUC: 0.6118321333838576
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9478021978021978, 0.28]
# Fold: 3
# ROC_AUC: 0.5863489958317545
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9313186813186813, 0.24]
# Fold: 4
# ROC_AUC: 0.5491189844638121
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9258241758241759, 0.17]
# Fold: 5
# ROC_AUC: 0.5755020841227738
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8406593406593407, 0.31]
# Fold: 6
# ROC_AUC: 0.4624384236453202
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8214285714285714, 0.1]
# Fold: 7
# ROC_AUC: 0.6316312997347481
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.7115384615384616, 0.55]
# Fold: 8
# ROC_AUC: 0.675767414403778
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9586776859504132, 0.39]
# Fold: 9
# ROC_AUC: 0.6716351829988193
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9504132231404959, 0.39]
# Fold: 10
# ROC_AUC: 0.5067886658795749
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9421487603305785, 0.07]
# Mean: 0.5880148065101043
# Std deviation: 0.06453358900226054
# Wall time: 1.45 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Random Forest

# %%
# %%time


base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', RandomForestClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_rfc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Random Forest - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Random Forest - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6263262599469496
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9423076923076923, 0.31]
# Fold: 2
# ROC_AUC: 0.6636983705949223
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8791208791208791, 0.45]
# Fold: 3
# ROC_AUC: 0.5794808639636226
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9175824175824175, 0.24]
# Fold: 4
# ROC_AUC: 0.5587343690791967
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.945054945054945, 0.17]
# Fold: 5
# ROC_AUC: 0.5602500947328534
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8791208791208791, 0.24]
# Fold: 6
# ROC_AUC: 0.4995263357332323
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8956043956043956, 0.1]
# Fold: 7
# ROC_AUC: 0.6116426676771504
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7060439560439561, 0.52]
# Fold: 8
# ROC_AUC: 0.6826544667453758
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9724517906336089, 0.39]
# Fold: 9
# ROC_AUC: 0.7265840220385674
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.953168044077135, 0.5]
# Fold: 10
# ROC_AUC: 0.4985733963006691
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9614325068870524, 0.04]
# Mean: 0.6007470846812539
# Std deviation: 0.07198753753253893
# Wall time: 3.23 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## KNN

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', KNeighborsClassifier())
    ])

clf = GridSearchCV(base_clf, parameters_knn_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['KNN - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['KNN - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5762599469496021
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8076923076923077, 0.34]
# Fold: 2
# ROC_AUC: 0.6729821902235694
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7252747252747253, 0.62]
# Fold: 3
# ROC_AUC: 0.5797650625236832
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7802197802197802, 0.38]
# Fold: 4
# ROC_AUC: 0.5610079575596818
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8461538461538461, 0.28]
# Fold: 5
# ROC_AUC: 0.5440507768093975
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7087912087912088, 0.38]
# Fold: 6
# ROC_AUC: 0.45509662751042057
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7032967032967034, 0.21]
# Fold: 7
# ROC_AUC: 0.5588291019325502
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.5659340659340659, 0.55]
# Fold: 8
# ROC_AUC: 0.7361275088547815
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.9008264462809917, 0.57]
# Fold: 9
# ROC_AUC: 0.7470484061393152
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8512396694214877, 0.64]
# Fold: 10
# ROC_AUC: 0.6290338449429359
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.9366391184573003, 0.32]
# Mean: 0.6060201423445938
# Std deviation: 0.08618389843118571
# Wall time: 3.11 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Adaboost

# %%
# %%time

adaboost_base = DecisionTreeClassifier(random_state = 42)

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', AdaBoostClassifier(random_state=42, base_estimator=adaboost_base))
    ])

clf = GridSearchCV(base_clf, parameters_ABC_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Adaboost - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Adaboost - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6490621447517999
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9532967032967034, 0.34]
# Fold: 2
# ROC_AUC: 0.6974232663887837
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9120879120879121, 0.48]
# Fold: 3
# ROC_AUC: 0.5800966275104206
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9532967032967034, 0.21]
# Fold: 4
# ROC_AUC: 0.5669761273209549
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9615384615384616, 0.17]
# Fold: 5
# ROC_AUC: 0.5926013641530884
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9093406593406593, 0.28]
# Fold: 6
# ROC_AUC: 0.48365858279651386
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.8983516483516484, 0.07]
# Fold: 7
# ROC_AUC: 0.5448086396362258
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.6758241758241759, 0.41]
# Fold: 8
# ROC_AUC: 0.6785222353404171
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9641873278236914, 0.39]
# Fold: 9
# ROC_AUC: 0.6771448248720976
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9614325068870524, 0.39]
# Fold: 10
# ROC_AUC: 0.5205627705627706
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9696969696969697, 0.07]
# Mean: 0.5990856583333073
# Std deviation: 0.06959902109515118
# Wall time: 32.4 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Gradient Boost

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', GradientBoostingClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_GBC, scoring='roc_auc', n_jobs=-1)


scores_list = list()

results_dict['Gradient Boost - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Gradient Boost - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6574460022735884
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9010989010989011, 0.41]
# Fold: 2
# ROC_AUC: 0.7843880257673361
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8791208791208791, 0.69]
# Fold: 3
# ROC_AUC: 0.6313471011746874
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8489010989010989, 0.41]
# Fold: 4
# ROC_AUC: 0.7029177718832892
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9230769230769231, 0.48]
# Fold: 5
# ROC_AUC: 0.6060060629026146
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7637362637362637, 0.45]
# Fold: 6
# ROC_AUC: 0.5268093974990526
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7087912087912088, 0.34]
# Fold: 7
# ROC_AUC: 0.6592459264873057
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6978021978021978, 0.62]
# Fold: 8
# ROC_AUC: 0.7403089334907517
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9449035812672176, 0.54]
# Fold: 9
# ROC_AUC: 0.7086776859504134
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9173553719008265, 0.5]
# Fold: 10
# ROC_AUC: 0.5508166076347895
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9944903581267218, 0.11]
# Mean: 0.6567963515063829
# Std deviation: 0.0770940331786345
# Wall time: 11.9 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## XGBoost

# %%
# %%time


base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', xgb.XGBClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, param_xgb_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['XGBoost - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['XGBoost - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6650719969685487
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8818681318681318, 0.45]
# Fold: 2
# ROC_AUC: 0.7851458885941645
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8461538461538461, 0.72]
# Fold: 3
# ROC_AUC: 0.6603353543008716
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8379120879120879, 0.48]
# Fold: 4
# ROC_AUC: 0.6933023872679045
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9038461538461539, 0.48]
# Fold: 5
# ROC_AUC: 0.6349943160287987
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7527472527472527, 0.52]
# Fold: 6
# ROC_AUC: 0.5048313755210307
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.6648351648351648, 0.34]
# Fold: 7
# ROC_AUC: 0.6351364153088291
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.6840659340659341, 0.59]
# Fold: 8
# ROC_AUC: 0.7512790240062968
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.931129476584022, 0.57]
# Fold: 9
# ROC_AUC: 0.7045454545454545
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9090909090909091, 0.5]
# Fold: 10
# ROC_AUC: 0.5645415190869736
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9862258953168044, 0.14]
# Mean: 0.6599183731628873
# Std deviation: 0.07845098905418535
# Wall time: 10.3 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Random OverSampler

# %%
sampler = RandomOverSampler(random_state=42)

# %% [markdown]
# ## Light GBM

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', lbm.LGBMClassifier())
    ])


clf = GridSearchCV(base_clf, param_lgm_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Light GBM - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Light GBM - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6263262599469496
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9423076923076923, 0.31]
# Fold: 2
# ROC_AUC: 0.6505778704054566
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8873626373626373, 0.41]
# Fold: 3
# ROC_AUC: 0.5561292156119743
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8708791208791209, 0.24]
# Fold: 4
# ROC_AUC: 0.6008431223948466
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9258241758241759, 0.28]
# Fold: 5
# ROC_AUC: 0.6333364910951118
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8873626373626373, 0.38]
# Fold: 6
# ROC_AUC: 0.5243937097385374
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8763736263736264, 0.17]
# Fold: 7
# ROC_AUC: 0.5512031072375899
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.5851648351648352, 0.52]
# Fold: 8
# ROC_AUC: 0.6867375049193232
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9449035812672176, 0.43]
# Fold: 9
# ROC_AUC: 0.663370720188902
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9338842975206612, 0.39]
# Fold: 10
# ROC_AUC: 0.5122983077528531
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.953168044077135, 0.07]
# Mean: 0.6005216309291544
# Std deviation: 0.05797708840247196
# Wall time: 3.98 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Logistic Regression

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', LogisticRegression(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_lr_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Logistic Regression - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Logistic Regression - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6554566123531641
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8626373626373627, 0.45]
# Fold: 2
# ROC_AUC: 0.7886510041682455
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8186813186813187, 0.76]
# Fold: 3
# ROC_AUC: 0.7196854869268662
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8186813186813187, 0.62]
# Fold: 4
# ROC_AUC: 0.6987968927624101
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9148351648351648, 0.48]
# Fold: 5
# ROC_AUC: 0.6025009473285334
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7912087912087912, 0.41]
# Fold: 6
# ROC_AUC: 0.5660287987874195
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7527472527472527, 0.38]
# Fold: 7
# ROC_AUC: 0.7558260704812428
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6840659340659341, 0.83]
# Fold: 8
# ROC_AUC: 0.7718417945690673
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9008264462809917, 0.64]
# Fold: 9
# ROC_AUC: 0.6948543880362061
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8539944903581267, 0.54]
# Fold: 10
# ROC_AUC: 0.7087268791814246
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.953168044077135, 0.46]
# Mean: 0.696236887459458
# Std deviation: 0.06776816877186864
# Wall time: 579 ms

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - Linear

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_linear, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM Linear - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM Linear - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6395888594164456
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8653846153846154, 0.41]
# Fold: 2
# ROC_AUC: 0.794761273209549
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8653846153846154, 0.72]
# Fold: 3
# ROC_AUC: 0.7430371352785146
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8653846153846154, 0.62]
# Fold: 4
# ROC_AUC: 0.7021599090564608
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9560439560439561, 0.45]
# Fold: 5
# ROC_AUC: 0.598237968927624
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8516483516483516, 0.34]
# Fold: 6
# ROC_AUC: 0.5707654414550967
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7967032967032966, 0.34]
# Fold: 7
# ROC_AUC: 0.7778040924592649
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.728021978021978, 0.83]
# Fold: 8
# ROC_AUC: 0.7554112554112554
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9393939393939394, 0.57]
# Fold: 9
# ROC_AUC: 0.6770464384100748
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8898071625344353, 0.46]
# Fold: 10
# ROC_AUC: 0.6977567886658795
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9669421487603306, 0.43]
# Mean: 0.6956569162290165
# Std deviation: 0.07142149912125956
# Wall time: 14.6 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - RBF

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_rbf, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM RBF - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM RBF - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.648446381205002
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9175824175824175, 0.38]
# Fold: 2
# ROC_AUC: 0.759520651762031
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8983516483516484, 0.62]
# Fold: 3
# ROC_AUC: 0.7105437665782492
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9038461538461539, 0.52]
# Fold: 4
# ROC_AUC: 0.7090280409245927
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9697802197802198, 0.45]
# Fold: 5
# ROC_AUC: 0.6174687381583933
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8901098901098901, 0.34]
# Fold: 6
# ROC_AUC: 0.5941170898067449
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8434065934065934, 0.34]
# Fold: 7
# ROC_AUC: 0.7259378552482001
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7967032967032966, 0.66]
# Fold: 8
# ROC_AUC: 0.7540338449429359
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9366391184573003, 0.57]
# Fold: 9
# ROC_AUC: 0.663370720188902
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9338842975206612, 0.39]
# Fold: 10
# ROC_AUC: 0.6675029515938606
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9421487603305785, 0.39]
# Mean: 0.6849970040408911
# Std deviation: 0.05306133445088294
# Wall time: 25.7 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Decision Tree

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', DecisionTreeClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_dtc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Decision Tree - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Decision Tree - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5684918529746116
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8956043956043956, 0.24]
# Fold: 2
# ROC_AUC: 0.605106100795756
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8653846153846154, 0.34]
# Fold: 3
# ROC_AUC: 0.5596343311860554
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8434065934065934, 0.28]
# Fold: 4
# ROC_AUC: 0.5401193633952255
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9423076923076923, 0.14]
# Fold: 5
# ROC_AUC: 0.5926013641530884
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9093406593406593, 0.28]
# Fold: 6
# ROC_AUC: 0.5228779840848806
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9423076923076923, 0.1]
# Fold: 7
# ROC_AUC: 0.4918529746115954
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.6043956043956044, 0.38]
# Fold: 8
# ROC_AUC: 0.6441361668634397
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.931129476584022, 0.36]
# Fold: 9
# ROC_AUC: 0.630362062180244
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9035812672176309, 0.36]
# Fold: 10
# ROC_AUC: 0.4930637544273908
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9504132231404959, 0.04]
# Mean: 0.5648245954672289
# Std deviation: 0.050857018716029864
# Wall time: 708 ms

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Random Forest

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', RandomForestClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_rfc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Random Forest - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Random Forest - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6139636225843121
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9175824175824175, 0.31]
# Fold: 2
# ROC_AUC: 0.6029746115953013
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8956043956043956, 0.31]
# Fold: 3
# ROC_AUC: 0.5602500947328534
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8791208791208791, 0.24]
# Fold: 4
# ROC_AUC: 0.5311197423266388
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9587912087912088, 0.1]
# Fold: 5
# ROC_AUC: 0.5877226222053809
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9340659340659341, 0.24]
# Fold: 6
# ROC_AUC: 0.5283724895793861
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9532967032967034, 0.1]
# Fold: 7
# ROC_AUC: 0.5469401288366805
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6456043956043956, 0.45]
# Fold: 8
# ROC_AUC: 0.6702577725304999
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9476584022038568, 0.39]
# Fold: 9
# ROC_AUC: 0.6386757182211728
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9559228650137741, 0.32]
# Fold: 10
# ROC_AUC: 0.49719598583234953
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9586776859504132, 0.04]
# Mean: 0.5777472788444575
# Std deviation: 0.05164664097474397
# Wall time: 2.38 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## KNN

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', KNeighborsClassifier())
    ])

clf = GridSearchCV(base_clf, parameters_knn_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['KNN - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['KNN - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6043482379689276
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8983516483516484, 0.31]
# Fold: 2
# ROC_AUC: 0.6603353543008716
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8379120879120879, 0.48]
# Fold: 3
# ROC_AUC: 0.5678760894278136
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8598901098901099, 0.28]
# Fold: 4
# ROC_AUC: 0.5643709738537325
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8873626373626373, 0.24]
# Fold: 5
# ROC_AUC: 0.5762599469496021
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8076923076923077, 0.34]
# Fold: 6
# ROC_AUC: 0.47418529746115956
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8104395604395604, 0.14]
# Fold: 7
# ROC_AUC: 0.519467601364153
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.5906593406593407, 0.45]
# Fold: 8
# ROC_AUC: 0.6949527744982291
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.9256198347107438, 0.46]
# Fold: 9
# ROC_AUC: 0.6811786698150335
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8980716253443526, 0.46]
# Fold: 10
# ROC_AUC: 0.5960743801652892
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.9421487603305785, 0.25]
# Mean: 0.5939049325804813
# Std deviation: 0.06639951042808569
# Wall time: 2.17 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Adaboost

# %%
# %%time

adaboost_base = DecisionTreeClassifier(random_state = 42)

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', AdaBoostClassifier(random_state=42, base_estimator=adaboost_base))
    ])

clf = GridSearchCV(base_clf, parameters_ABC_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Adaboost - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Adaboost - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.570481242895036
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9340659340659341, 0.21]
# Fold: 2
# ROC_AUC: 0.6070954907161803
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9038461538461539, 0.31]
# Fold: 3
# ROC_AUC: 0.5622394846532778
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9175824175824175, 0.21]
# Fold: 4
# ROC_AUC: 0.5393615005683972
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9752747252747253, 0.1]
# Fold: 5
# ROC_AUC: 0.5973380068207653
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9532967032967034, 0.24]
# Fold: 6
# ROC_AUC: 0.5111311102690412
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9532967032967034, 0.07]
# Fold: 7
# ROC_AUC: 0.5200833649109511
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.6263736263736264, 0.41]
# Fold: 8
# ROC_AUC: 0.6579102715466353
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9586776859504132, 0.36]
# Fold: 9
# ROC_AUC: 0.6414305391578119
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9614325068870524, 0.32]
# Fold: 10
# ROC_AUC: 0.5013282172373082
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9669421487603306, 0.04]
# Mean: 0.5708399228775404
# Std deviation: 0.05159373056578635
# Wall time: 9.99 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Gradient Boost

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', GradientBoostingClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_GBC, scoring='roc_auc', n_jobs=-1)


scores_list = list()

results_dict['Gradient Boost - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Gradient Boost - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6327207275483138
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8516483516483516, 0.41]
# Fold: 2
# ROC_AUC: 0.772167487684729
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7857142857142857, 0.76]
# Fold: 3
# ROC_AUC: 0.6520935960591133
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8214285714285714, 0.48]
# Fold: 4
# ROC_AUC: 0.6891815081470254
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8956043956043956, 0.48]
# Fold: 5
# ROC_AUC: 0.7184539598332702
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7472527472527473, 0.69]
# Fold: 6
# ROC_AUC: 0.6185107995452823
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7197802197802198, 0.52]
# Fold: 7
# ROC_AUC: 0.6311576354679803
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6071428571428571, 0.66]
# Fold: 8
# ROC_AUC: 0.71413813459268
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8925619834710744, 0.54]
# Fold: 9
# ROC_AUC: 0.7731208185753641
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8319559228650137, 0.71]
# Fold: 10
# ROC_AUC: 0.5356650924832743
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9641873278236914, 0.11]
# Mean: 0.6737209759937033
# Std deviation: 0.07036593737292088
# Wall time: 6.38 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## XGBoost

# %%
# %%time


base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', xgb.XGBClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, param_xgb_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['XGBoost - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['XGBoost - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6382152330428192
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8626373626373627, 0.41]
# Fold: 2
# ROC_AUC: 0.743179234558545
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7967032967032966, 0.69]
# Fold: 3
# ROC_AUC: 0.6279840848806366
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8076923076923077, 0.45]
# Fold: 4
# ROC_AUC: 0.7146646456991285
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9120879120879121, 0.52]
# Fold: 5
# ROC_AUC: 0.710212201591512
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7307692307692307, 0.69]
# Fold: 6
# ROC_AUC: 0.6116426676771504
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7060439560439561, 0.52]
# Fold: 7
# ROC_AUC: 0.6117847669571808
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.6373626373626373, 0.59]
# Fold: 8
# ROC_AUC: 0.6990358126721763
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8980716253443526, 0.5]
# Fold: 9
# ROC_AUC: 0.7167945690672963
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8264462809917356, 0.61]
# Fold: 10
# ROC_AUC: 0.5342876820149548
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9614325068870524, 0.11]
# Mean: 0.66078008981614
# Std deviation: 0.06256031342421964
# Wall time: 9.01 s

# %%
with open('base_Over_woo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
