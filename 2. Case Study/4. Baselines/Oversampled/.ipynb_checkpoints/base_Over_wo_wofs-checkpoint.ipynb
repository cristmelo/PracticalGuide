# %%
# %run auxiliary.ipynb

# %%
all_df = pd.read_excel('all_releases_no_repetitions.xlsx') # Original dataa

# %%
results_dict = dict()

# %%
k_fold = StratifiedKFold(10, random_state=42)

X_features = ['CBO','CC','DIT','LCOM','LOC','NOC','RFC','WMC']

X = pd.DataFrame(all_df.loc[:, X_features])

y = pd.DataFrame(all_df.loc[:, 'will_change'])
X = X.rename(columns={'CBO':'f0', 'CC':'f1', 'DIT':'f2', 'LCOM':'f3', 'LOC':'f4', 'NOC':'f5', 'RFC':'f6', 'WMC':'f7'})

# %%
X.head()
# Out:
#    f0  f1  f2   f3   f4  f5  f6  f7
# 0   0   2   0  0.0  210   0   0   1
# 1   0   2   0  0.0    2   0   0   1
# 2  21   9   0  0.0   33   0  18   4
# 3   1   7   2  0.0   11   0   2   2
# 4   1   2   0  0.0    3   0   1   1

# %%
parameters_svc_linear = {
        'clf__kernel':['linear'],
    'clf__max_iter':[10000],
    }

parameters_svc_rbf = {
        'clf__kernel':['rbf'],
    }

parameters_dtc_grid = {
    'clf__criterion':['gini'], 
}

parameters_rfc_grid = { 
    'clf__criterion' :['gini'],
}

parameters_ABC_grid = {
    'clf__base_estimator__criterion' : ["gini"],
}


parameters_knn_grid = {'clf__n_neighbors': [5]}


parameters_lr_grid = [{
                        'clf__penalty':['l2'],
                        }]

parameters_GBC = {
    "clf__loss":["deviance"],
    }


param_xgb_grid = {
           'clf__clf__random_state': [42] #ensemble xgboost with multiple seeds may reduce variance
             }

param_lgm_grid = {
    "clf__random_state":[42]
}

# %% [markdown]
# # SMOTE

# %%
sampler = SMOTE(random_state=42)

# %% [markdown]
# ## Light GBM

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', lbm.LGBMClassifier())
    ])


clf = GridSearchCV(base_clf, param_lgm_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Light GBM - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Light GBM - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.557506443298969
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9587628865979382, 0.16]
# Fold: 2
# ROC_AUC: 0.604328165374677
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.958656330749354, 0.25]
# Fold: 3
# ROC_AUC: 0.5722263899308161
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9509043927648578, 0.19]
# Fold: 4
# ROC_AUC: 0.5528882220555138
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9767441860465116, 0.13]
# Fold: 5
# ROC_AUC: 0.5838126198216221
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9095607235142119, 0.26]
# Fold: 6
# ROC_AUC: 0.4992914895390514
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9018087855297158, 0.1]
# Fold: 7
# ROC_AUC: 0.5610986079853297
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.7028423772609819, 0.42]
# Fold: 8
# ROC_AUC: 0.5167541885471367
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9689922480620154, 0.06]
# Fold: 9
# ROC_AUC: 0.5896474118529632
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9534883720930233, 0.23]
# Fold: 10
# ROC_AUC: 0.4935400516795866
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9870801033591732, 0.0]
# Mean: 0.5531093590085666
# Std deviation: 0.03621646275833586
# CPU times: user 8.55 s, sys: 109 ms, total: 8.65 s
# Wall time: 6.01 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Logistic Regression

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', LogisticRegression(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_lr_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Logistic Regression - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Logistic Regression - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6884664948453608
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8144329896907216, 0.56]
# Fold: 2
# ROC_AUC: 0.7405119509043927
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7622739018087855, 0.72]
# Fold: 3
# ROC_AUC: 0.7288905559723263
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7803617571059431, 0.68]
# Fold: 4
# ROC_AUC: 0.636700841877136
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8863049095607235, 0.39]
# Fold: 5
# ROC_AUC: 0.5933983495873969
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7674418604651163, 0.42]
# Fold: 6
# ROC_AUC: 0.618529632408102
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7209302325581395, 0.52]
# Fold: 7
# ROC_AUC: 0.6164874551971326
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.5555555555555556, 0.68]
# Fold: 8
# ROC_AUC: 0.7515212136367425
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8578811369509044, 0.65]
# Fold: 9
# ROC_AUC: 0.6818371259481537
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8475452196382429, 0.52]
# Fold: 10
# ROC_AUC: 0.6212386429940818
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9198966408268734, 0.32]
# Mean: 0.6677582263370826
# Std deviation: 0.05512143183274365
# CPU times: user 945 ms, sys: 24.5 ms, total: 969 ms
# Wall time: 1.16 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - Linear

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_linear, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM Linear - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM Linear - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6388530927835052
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8402061855670103, 0.44]
# Fold: 2
# ROC_AUC: 0.7924337855297158
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8036175710594315, 0.78]
# Fold: 3
# ROC_AUC: 0.7121363674251896
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8113695090439277, 0.61]
# Fold: 4
# ROC_AUC: 0.596732516462449
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9354005167958657, 0.26]
# Fold: 5
# ROC_AUC: 0.5876052346419939
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7881136950904393, 0.39]
# Fold: 6
# ROC_AUC: 0.58047845294657
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7416020671834626, 0.42]
# Fold: 7
# ROC_AUC: 0.6390764357756106
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.5684754521963824, 0.71]
# Fold: 8
# ROC_AUC: 0.7043844294406936
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7958656330749354, 0.61]
# Fold: 9
# ROC_AUC: 0.6715428857214304
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8914728682170543, 0.45]
# Fold: 10
# ROC_AUC: 0.6257814453613403
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9612403100775194, 0.29]
# Mean: 0.6549024646088498
# Std deviation: 0.06302668097826412
# CPU times: user 7min 27s, sys: 362 ms, total: 7min 27s
# Wall time: 12min 58s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - RBF

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_rbf, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM RBF - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM RBF - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5687822164948454
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7938144329896907, 0.34]
# Fold: 2
# ROC_AUC: 0.6117571059431526
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7235142118863049, 0.5]
# Fold: 3
# ROC_AUC: 0.6024422772359757
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7855297157622739, 0.42]
# Fold: 4
# ROC_AUC: 0.5624739518212887
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.834625322997416, 0.29]
# Fold: 5
# ROC_AUC: 0.6005251312828208
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.813953488372093, 0.39]
# Fold: 6
# ROC_AUC: 0.5127948653830124
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8320413436692506, 0.19]
# Fold: 7
# ROC_AUC: 0.5383429190630991
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.4315245478036176, 0.65]
# Fold: 8
# ROC_AUC: 0.449570726014837
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.834625322997416, 0.06]
# Fold: 9
# ROC_AUC: 0.6230307576894224
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.6976744186046512, 0.55]
# Fold: 10
# ROC_AUC: 0.6721680420105026
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8604651162790697, 0.48]
# Mean: 0.5741887992938957
# Std deviation: 0.05969839461275823
# CPU times: user 17.6 s, sys: 72 ms, total: 17.7 s
# Wall time: 31.2 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Decision Tree

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', DecisionTreeClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_dtc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Decision Tree - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Decision Tree - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5093427835051547
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9561855670103093, 0.06]
# Fold: 2
# ROC_AUC: 0.5978682170542636
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9457364341085271, 0.25]
# Fold: 3
# ROC_AUC: 0.5296324081020254
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9302325581395349, 0.13]
# Fold: 4
# ROC_AUC: 0.5302992414770359
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9638242894056848, 0.1]
# Fold: 5
# ROC_AUC: 0.5741018587980328
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8578811369509044, 0.29]
# Fold: 6
# ROC_AUC: 0.4773276652496457
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8578811369509044, 0.1]
# Fold: 7
# ROC_AUC: 0.4442777361006919
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.6304909560723514, 0.26]
# Fold: 8
# ROC_AUC: 0.4980411769609069
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9638242894056848, 0.03]
# Fold: 9
# ROC_AUC: 0.5980245061265316
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.937984496124031, 0.26]
# Fold: 10
# ROC_AUC: 0.479328165374677
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.958656330749354, 0.0]
# Mean: 0.5238243758748966
# Std deviation: 0.049935605302204256
# CPU times: user 594 ms, sys: 16 ms, total: 610 ms
# Wall time: 1.06 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Random Forest

# %%
# %%time


base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', RandomForestClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_rfc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Random Forest - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Random Forest - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5459085051546392
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9355670103092784, 0.16]
# Fold: 2
# ROC_AUC: 0.5393653100775193
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9224806201550387, 0.16]
# Fold: 3
# ROC_AUC: 0.5806034842043845
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9354005167958657, 0.23]
# Fold: 4
# ROC_AUC: 0.5264232724847878
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9560723514211886, 0.1]
# Fold: 5
# ROC_AUC: 0.5225473034925399
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9483204134366925, 0.1]
# Fold: 6
# ROC_AUC: 0.5018754688672168
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9069767441860465, 0.1]
# Fold: 7
# ROC_AUC: 0.5055847295157123
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6563307493540051, 0.35]
# Fold: 8
# ROC_AUC: 0.4967491872968242
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9612403100775194, 0.03]
# Fold: 9
# ROC_AUC: 0.6057764441110277
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9534883720930233, 0.26]
# Fold: 10
# ROC_AUC: 0.4870801033591731
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9741602067183462, 0.0]
# Mean: 0.5311913808563825
# Std deviation: 0.03610061246527538
# CPU times: user 860 ms, sys: 24 ms, total: 884 ms
# Wall time: 1.67 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## KNN

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', KNeighborsClassifier())
    ])

clf = GridSearchCV(base_clf, parameters_knn_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['KNN - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['KNN - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6557667525773196
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8427835051546392, 0.47]
# Fold: 2
# ROC_AUC: 0.6441779715762274
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7571059431524548, 0.53]
# Fold: 3
# ROC_AUC: 0.5669334000166709
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7467700258397932, 0.39]
# Fold: 4
# ROC_AUC: 0.561181962157206
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8320413436692506, 0.29]
# Fold: 5
# ROC_AUC: 0.6101525381345336
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7364341085271318, 0.48]
# Fold: 6
# ROC_AUC: 0.6076102358923064
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7958656330749354, 0.42]
# Fold: 7
# ROC_AUC: 0.4719096440776861
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.4599483204134367, 0.48]
# Fold: 8
# ROC_AUC: 0.5663499208135367
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8423772609819121, 0.29]
# Fold: 9
# ROC_AUC: 0.5656414103525882
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7441860465116279, 0.39]
# Fold: 10
# ROC_AUC: 0.6347836959239811
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.9147286821705426, 0.35]
# Mean: 0.5884507531522056
# Std deviation: 0.05139930733937994
# CPU times: user 620 ms, sys: 12 ms, total: 632 ms
# Wall time: 1.39 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Adaboost

# %%
# %%time

adaboost_base = DecisionTreeClassifier(random_state = 42)

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', AdaBoostClassifier(random_state=42, base_estimator=adaboost_base))
    ])

clf = GridSearchCV(base_clf, parameters_ABC_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Adaboost - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Adaboost - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5497744845360825
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9432989690721649, 0.16]
# Fold: 2
# ROC_AUC: 0.5316133720930233
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9069767441860465, 0.16]
# Fold: 3
# ROC_AUC: 0.5244644494456947
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9198966408268734, 0.13]
# Fold: 4
# ROC_AUC: 0.5251312828207051
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9534883720930233, 0.1]
# Fold: 5
# ROC_AUC: 0.5470534300241727
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9328165374677002, 0.16]
# Fold: 6
# ROC_AUC: 0.49349837459364837
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9224806201550387, 0.06]
# Fold: 7
# ROC_AUC: 0.4513628407101775
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.6124031007751938, 0.29]
# Fold: 8
# ROC_AUC: 0.4980411769609069
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9638242894056848, 0.03]
# Fold: 9
# ROC_AUC: 0.6315745603067433
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9405684754521964, 0.32]
# Fold: 10
# ROC_AUC: 0.4870801033591731
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9741602067183462, 0.0]
# Mean: 0.5239594074850328
# Std deviation: 0.045903113738667234
# CPU times: user 19.5 s, sys: 4.02 ms, total: 19.5 s
# Wall time: 44.3 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Gradient Boost

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', GradientBoostingClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_GBC, scoring='roc_auc', n_jobs=-1)


scores_list = list()

results_dict['Gradient Boost - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Gradient Boost - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6984536082474228
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8969072164948454, 0.5]
# Fold: 2
# ROC_AUC: 0.6436934754521964
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8811369509043928, 0.41]
# Fold: 3
# ROC_AUC: 0.6528298741352004
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8863049095607235, 0.42]
# Fold: 4
# ROC_AUC: 0.5496374093523381
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.937984496124031, 0.16]
# Fold: 5
# ROC_AUC: 0.6076519129782446
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8604651162790697, 0.35]
# Fold: 6
# ROC_AUC: 0.5373009919146453
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8165374677002584, 0.26]
# Fold: 7
# ROC_AUC: 0.567516879219805
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6511627906976745, 0.48]
# Fold: 8
# ROC_AUC: 0.6825456364091023
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9457364341085271, 0.42]
# Fold: 9
# ROC_AUC: 0.7231807951987996
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9302325581395349, 0.52]
# Fold: 10
# ROC_AUC: 0.5096690839376511
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9870801033591732, 0.03]
# Mean: 0.6172479666845405
# Std deviation: 0.07010458664010062
# CPU times: user 3.4 s, sys: 4.01 ms, total: 3.4 s
# Wall time: 6.92 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## XGBoost

# %%
# %%time


base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', xgb.XGBClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, param_xgb_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['XGBoost - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['XGBoost - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6932989690721649
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8865979381443299, 0.5]
# Fold: 2
# ROC_AUC: 0.6749434754521965
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8811369509043928, 0.47]
# Fold: 3
# ROC_AUC: 0.6624989580728516
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8733850129198967, 0.45]
# Fold: 4
# ROC_AUC: 0.5496374093523381
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.937984496124031, 0.16]
# Fold: 5
# ROC_AUC: 0.6250729349003918
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8630490956072352, 0.39]
# Fold: 6
# ROC_AUC: 0.5495540551804617
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8087855297157622, 0.29]
# Fold: 7
# ROC_AUC: 0.5958989747436859
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.6434108527131783, 0.55]
# Fold: 8
# ROC_AUC: 0.6677085938151205
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9483204134366925, 0.39]
# Fold: 9
# ROC_AUC: 0.6844627823622573
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.917312661498708, 0.45]
# Fold: 10
# ROC_AUC: 0.5419271484537801
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9870801033591732, 0.1]
# Mean: 0.6245003301405249
# Std deviation: 0.05748235021176858
# CPU times: user 2.73 s, sys: 8 ms, total: 2.73 s
# Wall time: 5.6 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # ADASYN

# %%
sampler = ADASYN(random_state=42)

# %% [markdown]
# ## Light GBM

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', lbm.LGBMClassifier())
    ])


clf = GridSearchCV(base_clf, param_lgm_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Light GBM - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Light GBM - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5587951030927836
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.961340206185567, 0.16]
# Fold: 2
# ROC_AUC: 0.604328165374677
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.958656330749354, 0.25]
# Fold: 3
# ROC_AUC: 0.5631824622822372
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9328165374677002, 0.19]
# Fold: 4
# ROC_AUC: 0.538051179461532
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.979328165374677, 0.1]
# Fold: 5
# ROC_AUC: 0.5889805784779528
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9198966408268734, 0.26]
# Fold: 6
# ROC_AUC: 0.5005834792031341
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9043927648578811, 0.1]
# Fold: 7
# ROC_AUC: 0.5204634491956323
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.7183462532299741, 0.32]
# Fold: 8
# ROC_AUC: 0.5528882220555138
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9767441860465116, 0.13]
# Fold: 9
# ROC_AUC: 0.627073435025423
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9638242894056848, 0.29]
# Fold: 10
# ROC_AUC: 0.49224806201550386
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9844961240310077, 0.0]
# Mean: 0.554659413618439
# Std deviation: 0.04152852282056778
# CPU times: user 2.13 s, sys: 8.04 ms, total: 2.14 s
# Wall time: 4.81 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Logistic Regression

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', LogisticRegression(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_lr_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Logistic Regression - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Logistic Regression - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6717139175257733
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7809278350515464, 0.56]
# Fold: 2
# ROC_AUC: 0.7653020025839793
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7493540051679587, 0.78]
# Fold: 3
# ROC_AUC: 0.7191797949487372
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7286821705426356, 0.71]
# Fold: 4
# ROC_AUC: 0.6657080936900892
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8475452196382429, 0.48]
# Fold: 5
# ROC_AUC: 0.5856464116029008
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.751937984496124, 0.42]
# Fold: 6
# ROC_AUC: 0.5862298908060348
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6563307493540051, 0.52]
# Fold: 7
# ROC_AUC: 0.6145286321580397
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.5193798449612403, 0.71]
# Fold: 8
# ROC_AUC: 0.7476035675585564
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7855297157622739, 0.71]
# Fold: 9
# ROC_AUC: 0.6766691672918229
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8372093023255814, 0.52]
# Fold: 10
# ROC_AUC: 0.6257397682754021
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.896640826873385, 0.35]
# Mean: 0.6658321246441334
# Std deviation: 0.06048517287199024
# CPU times: user 760 ms, sys: 8 ms, total: 768 ms
# Wall time: 1.28 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - Linear

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_linear, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM Linear - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM Linear - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.629993556701031
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7912371134020618, 0.47]
# Fold: 2
# ROC_AUC: 0.783389857881137
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7855297157622739, 0.78]
# Fold: 3
# ROC_AUC: 0.7153455030424272
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7855297157622739, 0.65]
# Fold: 4
# ROC_AUC: 0.6412019671584563
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8630490956072352, 0.42]
# Fold: 5
# ROC_AUC: 0.578561306993415
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7700258397932817, 0.39]
# Fold: 6
# ROC_AUC: 0.5888555472201383
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7260981912144703, 0.45]
# Fold: 7
# ROC_AUC: 0.6261565391347838
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.5426356589147286, 0.71]
# Fold: 8
# ROC_AUC: 0.6074852046344918
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.6020671834625323, 0.61]
# Fold: 9
# ROC_AUC: 0.6663749270650996
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8811369509043928, 0.45]
# Fold: 10
# ROC_AUC: 0.6206134867050096
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9509043927648578, 0.29]
# Mean: 0.645797789653599
# Std deviation: 0.058918436169066356
# CPU times: user 7min 2s, sys: 604 ms, total: 7min 2s
# Wall time: 12min 31s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - RBF

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_rbf, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM RBF - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM RBF - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5610502577319588
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7783505154639175, 0.34]
# Fold: 2
# ROC_AUC: 0.6130490956072351
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7260981912144703, 0.5]
# Fold: 3
# ROC_AUC: 0.6082353921813787
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7648578811369509, 0.45]
# Fold: 4
# ROC_AUC: 0.5573059931649579
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8242894056847545, 0.29]
# Fold: 5
# ROC_AUC: 0.5901892139701592
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7932816537467701, 0.39]
# Fold: 6
# ROC_AUC: 0.5089188963907644
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8242894056847545, 0.19]
# Fold: 7
# ROC_AUC: 0.5118779694923731
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.4108527131782946, 0.61]
# Fold: 8
# ROC_AUC: 0.45794782028840547
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8191214470284238, 0.1]
# Fold: 9
# ROC_AUC: 0.620446778361257
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.6925064599483204, 0.55]
# Fold: 10
# ROC_AUC: 0.6721680420105026
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8604651162790697, 0.48]
# Mean: 0.5701189459198992
# Std deviation: 0.060507699762370915
# CPU times: user 17.1 s, sys: 80 ms, total: 17.2 s
# Wall time: 30.5 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Decision Tree

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', DecisionTreeClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_dtc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Decision Tree - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Decision Tree - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.541881443298969
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9587628865979382, 0.12]
# Fold: 2
# ROC_AUC: 0.5653262273901809
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9431524547803618, 0.19]
# Fold: 3
# ROC_AUC: 0.5709344002667334
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9483204134366925, 0.19]
# Fold: 4
# ROC_AUC: 0.5522213886805035
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9431524547803618, 0.16]
# Fold: 5
# ROC_AUC: 0.547678586313245
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9018087855297158, 0.19]
# Fold: 6
# ROC_AUC: 0.47215970659331497
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8475452196382429, 0.1]
# Fold: 7
# ROC_AUC: 0.5236309077269318
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.627906976744186, 0.42]
# Fold: 8
# ROC_AUC: 0.4864132699841627
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9405684754521964, 0.03]
# Fold: 9
# ROC_AUC: 0.5954405267983662
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9328165374677002, 0.26]
# Fold: 10
# ROC_AUC: 0.4909560723514212
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9819121447028424, 0.0]
# Mean: 0.5346642529403829
# Std deviation: 0.03840086572044385
# CPU times: user 693 ms, sys: 8.03 ms, total: 701 ms
# Wall time: 1.21 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Random Forest

# %%
# %%time


base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', RandomForestClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_rfc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Random Forest - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Random Forest - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5523518041237113
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9484536082474226, 0.16]
# Fold: 2
# ROC_AUC: 0.5744912790697675
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9302325581395349, 0.22]
# Fold: 3
# ROC_AUC: 0.5605984829540719
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9276485788113695, 0.19]
# Fold: 4
# ROC_AUC: 0.5425523047428523
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9560723514211886, 0.13]
# Fold: 5
# ROC_AUC: 0.5567225139618238
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9198966408268734, 0.19]
# Fold: 6
# ROC_AUC: 0.4857464366091523
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9069767441860465, 0.06]
# Fold: 7
# ROC_AUC: 0.48687171792948236
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6511627906976745, 0.32]
# Fold: 8
# ROC_AUC: 0.4954571976327415
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.958656330749354, 0.03]
# Fold: 9
# ROC_AUC: 0.5761023589230642
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.958656330749354, 0.19]
# Fold: 10
# ROC_AUC: 0.49483204134366926
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9896640826873385, 0.0]
# Mean: 0.5325726137290336
# Std deviation: 0.03548895392879073
# CPU times: user 957 ms, sys: 12 ms, total: 969 ms
# Wall time: 1.84 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## KNN

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', KNeighborsClassifier())
    ])

clf = GridSearchCV(base_clf, parameters_knn_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['KNN - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['KNN - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6232280927835051
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8402061855670103, 0.41]
# Fold: 2
# ROC_AUC: 0.6027131782945736
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7054263565891473, 0.5]
# Fold: 3
# ROC_AUC: 0.5688505459698259
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7183462532299741, 0.42]
# Fold: 4
# ROC_AUC: 0.5585979828290406
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8268733850129198, 0.29]
# Fold: 5
# ROC_AUC: 0.6024006001500375
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7209302325581395, 0.48]
# Fold: 6
# ROC_AUC: 0.5882303909310661
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7571059431524548, 0.42]
# Fold: 7
# ROC_AUC: 0.4712428107026757
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.4263565891472868, 0.52]
# Fold: 8
# ROC_AUC: 0.6011919646578312
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8475452196382429, 0.35]
# Fold: 9
# ROC_AUC: 0.5791864632824874
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7390180878552972, 0.42]
# Fold: 10
# ROC_AUC: 0.6121947153455031
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.9018087855297158, 0.32]
# Mean: 0.5807836744946545
# Std deviation: 0.041042277021387644
# CPU times: user 688 ms, sys: 19 µs, total: 688 ms
# Wall time: 1.49 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Adaboost

# %%
# %%time

adaboost_base = DecisionTreeClassifier(random_state = 42)

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', AdaBoostClassifier(random_state=42, base_estimator=adaboost_base))
    ])

clf = GridSearchCV(base_clf, parameters_ABC_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Adaboost - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Adaboost - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5407538659793815
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9252577319587629, 0.16]
# Fold: 2
# ROC_AUC: 0.5628633720930233
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9069767441860465, 0.22]
# Fold: 3
# ROC_AUC: 0.5806034842043845
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9354005167958657, 0.23]
# Fold: 4
# ROC_AUC: 0.5264232724847878
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9560723514211886, 0.1]
# Fold: 5
# ROC_AUC: 0.5618904726181545
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9302325581395349, 0.19]
# Fold: 6
# ROC_AUC: 0.4896224056014003
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9147286821705426, 0.06]
# Fold: 7
# ROC_AUC: 0.5010419271484539
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.6149870801033591, 0.39]
# Fold: 8
# ROC_AUC: 0.5045011252813203
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9767441860465116, 0.03]
# Fold: 9
# ROC_AUC: 0.608360423439193
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.958656330749354, 0.26]
# Fold: 10
# ROC_AUC: 0.5122530632658164
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9922480620155039, 0.03]
# Mean: 0.5388313412115917
# Std deviation: 0.03685193518616238
# CPU times: user 20.1 s, sys: 7.99 ms, total: 20.2 s
# Wall time: 41 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Gradient Boost

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', GradientBoostingClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_GBC, scoring='roc_auc', n_jobs=-1)


scores_list = list()

results_dict['Gradient Boost - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Gradient Boost - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.7063466494845361
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8814432989690721, 0.53]
# Fold: 2
# ROC_AUC: 0.6528585271317829
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8682170542635659, 0.44]
# Fold: 3
# ROC_AUC: 0.6676669167291823
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8837209302325582, 0.45]
# Fold: 4
# ROC_AUC: 0.5780195048762191
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9302325581395349, 0.23]
# Fold: 5
# ROC_AUC: 0.5850629323997666
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8475452196382429, 0.32]
# Fold: 6
# ROC_AUC: 0.6166541635408853
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.813953488372093, 0.42]
# Fold: 7
# ROC_AUC: 0.5584729515712261
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6330749354005168, 0.48]
# Fold: 8
# ROC_AUC: 0.6528715512211386
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9509043927648578, 0.35]
# Fold: 9
# ROC_AUC: 0.6857547720263399
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9198966408268734, 0.45]
# Fold: 10
# ROC_AUC: 0.5419271484537801
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9870801033591732, 0.1]
# Mean: 0.6245635117434858
# Std deviation: 0.053738847479639716
# CPU times: user 3.42 s, sys: 8.04 ms, total: 3.43 s
# Wall time: 7.01 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## XGBoost

# %%
# %%time


base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', xgb.XGBClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, param_xgb_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['XGBoost - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['XGBoost - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6842783505154639
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8685567010309279, 0.5]
# Fold: 2
# ROC_AUC: 0.6320655684754521
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8578811369509044, 0.41]
# Fold: 3
# ROC_AUC: 0.6663749270650996
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8811369509043928, 0.45]
# Fold: 4
# ROC_AUC: 0.5702675668917229
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9147286821705426, 0.23]
# Fold: 5
# ROC_AUC: 0.6011919646578312
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8475452196382429, 0.35]
# Fold: 6
# ROC_AUC: 0.59535717262649
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8036175710594315, 0.39]
# Fold: 7
# ROC_AUC: 0.586855047095107
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.6253229974160207, 0.55]
# Fold: 8
# ROC_AUC: 0.6664166041510379
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9457364341085271, 0.39]
# Fold: 9
# ROC_AUC: 0.7257647745269651
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9354005167958657, 0.52]
# Fold: 10
# ROC_AUC: 0.5619321497040926
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9948320413436692, 0.13]
# Mean: 0.6290504125709262
# Std deviation: 0.051821131134750155
# CPU times: user 2.81 s, sys: 8.02 ms, total: 2.82 s
# Wall time: 5.72 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Random OverSampler

# %%
sampler = RandomOverSampler(random_state=42)

# %% [markdown]
# ## Light GBM

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', lbm.LGBMClassifier())
    ])


clf = GridSearchCV(base_clf, param_lgm_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Light GBM - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Light GBM - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5837628865979381
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9175257731958762, 0.25]
# Fold: 2
# ROC_AUC: 0.5840197028423773
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8242894056847545, 0.34]
# Fold: 3
# ROC_AUC: 0.6457030924397766
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8397932816537468, 0.45]
# Fold: 4
# ROC_AUC: 0.5973576727515212
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9043927648578811, 0.29]
# Fold: 5
# ROC_AUC: 0.6476202383929317
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8113695090439277, 0.48]
# Fold: 6
# ROC_AUC: 0.532799866633325
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8397932816537468, 0.23]
# Fold: 7
# ROC_AUC: 0.43194131866299906
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.5090439276485789, 0.35]
# Fold: 8
# ROC_AUC: 0.5767275152121364
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9276485788113695, 0.23]
# Fold: 9
# ROC_AUC: 0.5844377761106943
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8785529715762274, 0.29]
# Fold: 10
# ROC_AUC: 0.5290072518129532
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9612403100775194, 0.1]
# Mean: 0.5713377321456653
# Std deviation: 0.05937216466724934
# CPU times: user 1.49 s, sys: 16 ms, total: 1.51 s
# Wall time: 3.09 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Logistic Regression

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', LogisticRegression(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_lr_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Logistic Regression - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Logistic Regression - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.679284793814433
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8273195876288659, 0.53]
# Fold: 2
# ROC_AUC: 0.7573078165374677
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7958656330749354, 0.72]
# Fold: 3
# ROC_AUC: 0.7192214720346753
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7932816537467701, 0.65]
# Fold: 4
# ROC_AUC: 0.6457447695257148
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9043927648578811, 0.39]
# Fold: 5
# ROC_AUC: 0.6089022255563891
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7984496124031008, 0.42]
# Fold: 6
# ROC_AUC: 0.5940235058764691
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7364341085271318, 0.45]
# Fold: 7
# ROC_AUC: 0.6300325081270317
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.5503875968992248, 0.71]
# Fold: 8
# ROC_AUC: 0.7521880470117529
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8914728682170543, 0.61]
# Fold: 9
# ROC_AUC: 0.7166791697924481
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8527131782945736, 0.58]
# Fold: 10
# ROC_AUC: 0.6231974660331749
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9560723514211886, 0.29]
# Mean: 0.6726581774309557
# Std deviation: 0.05733788967559622
# CPU times: user 545 ms, sys: 8.01 ms, total: 553 ms
# Wall time: 905 ms

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - Linear

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_linear, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM Linear - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM Linear - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6607603092783505
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.884020618556701, 0.44]
# Fold: 2
# ROC_AUC: 0.7702277131782945
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8217054263565892, 0.72]
# Fold: 3
# ROC_AUC: 0.7160123364174377
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8191214470284238, 0.61]
# Fold: 4
# ROC_AUC: 0.6167375177127615
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9431524547803618, 0.29]
# Fold: 5
# ROC_AUC: 0.6082770692673168
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8294573643410853, 0.39]
# Fold: 6
# ROC_AUC: 0.5759773276652497
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7648578811369509, 0.39]
# Fold: 7
# ROC_AUC: 0.6429524047678586
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.5762273901808785, 0.71]
# Fold: 8
# ROC_AUC: 0.7128448778861382
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9095607235142119, 0.52]
# Fold: 9
# ROC_AUC: 0.6986329915812286
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8811369509043928, 0.52]
# Fold: 10
# ROC_AUC: 0.6135283820955238
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9689922480620154, 0.26]
# Mean: 0.6615950929850161
# Std deviation: 0.057969560781522156
# CPU times: user 12min 1s, sys: 168 ms, total: 12min 1s
# Wall time: 22min 25s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - RBF

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_rbf, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM RBF - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM RBF - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.49114046391752575
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9510309278350515, 0.03]
# Fold: 2
# ROC_AUC: 0.4639454134366925
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.896640826873385, 0.03]
# Fold: 3
# ROC_AUC: 0.49479036425773104
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9250645994832042, 0.06]
# Fold: 4
# ROC_AUC: 0.5083354171876302
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9198966408268734, 0.1]
# Fold: 5
# ROC_AUC: 0.5199633241643744
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9431524547803618, 0.1]
# Fold: 6
# ROC_AUC: 0.5315912311411186
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9664082687338501, 0.1]
# Fold: 7
# ROC_AUC: 0.34233558389597396
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.6201550387596899, 0.06]
# Fold: 8
# ROC_AUC: 0.4941652079686588
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9560723514211886, 0.03]
# Fold: 9
# ROC_AUC: 0.49608235392181377
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9276485788113695, 0.06]
# Fold: 10
# ROC_AUC: 0.4915812286404934
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9509043927648578, 0.03]
# Mean: 0.4833930588532012
# Std deviation: 0.05009193138195792
# CPU times: user 11.1 s, sys: 16 ms, total: 11.2 s
# Wall time: 19.8 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Decision Tree

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', DecisionTreeClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_dtc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Decision Tree - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Decision Tree - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5070876288659794
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8891752577319587, 0.12]
# Fold: 2
# ROC_AUC: 0.5304425064599483
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8733850129198967, 0.19]
# Fold: 3
# ROC_AUC: 0.5702258898057848
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8501291989664083, 0.29]
# Fold: 4
# ROC_AUC: 0.5393014920396767
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.917312661498708, 0.16]
# Fold: 5
# ROC_AUC: 0.5037926148203717
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8785529715762274, 0.13]
# Fold: 6
# ROC_AUC: 0.48445444694506956
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9043927648578811, 0.06]
# Fold: 7
# ROC_AUC: 0.4661582062182212
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.5452196382428941, 0.39]
# Fold: 8
# ROC_AUC: 0.48124531132783194
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9302325581395349, 0.03]
# Fold: 9
# ROC_AUC: 0.5393014920396767
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.917312661498708, 0.16]
# Fold: 10
# ROC_AUC: 0.5128782195548888
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9612403100775194, 0.06]
# Mean: 0.5134887808077448
# Std deviation: 0.030161732041176663
# CPU times: user 338 ms, sys: 12 ms, total: 350 ms
# Wall time: 548 ms

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Random Forest

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', RandomForestClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_rfc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Random Forest - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Random Forest - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5409149484536083
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8943298969072165, 0.19]
# Fold: 2
# ROC_AUC: 0.5278585271317829
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8682170542635659, 0.19]
# Fold: 3
# ROC_AUC: 0.5625156289072268
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8992248062015504, 0.23]
# Fold: 4
# ROC_AUC: 0.539968325414687
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9509043927648578, 0.13]
# Fold: 5
# ROC_AUC: 0.5535133783445862
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9457364341085271, 0.16]
# Fold: 6
# ROC_AUC: 0.5083354171876302
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9198966408268734, 0.1]
# Fold: 7
# ROC_AUC: 0.42489789113945153
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.5917312661498708, 0.26]
# Fold: 8
# ROC_AUC: 0.4915812286404934
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9509043927648578, 0.03]
# Fold: 9
# ROC_AUC: 0.5806034842043845
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9354005167958657, 0.23]
# Fold: 10
# ROC_AUC: 0.49933316662498956
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9664082687338501, 0.03]
# Mean: 0.522952199604884
# Std deviation: 0.042224988346587146
# CPU times: user 647 ms, sys: 0 ns, total: 647 ms
# Wall time: 1.13 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## KNN

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', KNeighborsClassifier())
    ])

clf = GridSearchCV(base_clf, parameters_knn_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['KNN - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['KNN - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6401417525773195
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8427835051546392, 0.44]
# Fold: 2
# ROC_AUC: 0.640059754521964
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8113695090439277, 0.47]
# Fold: 3
# ROC_AUC: 0.5959823289155622
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.772609819121447, 0.42]
# Fold: 4
# ROC_AUC: 0.5683087438526297
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8785529715762274, 0.26]
# Fold: 5
# ROC_AUC: 0.5818121196965909
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8087855297157622, 0.35]
# Fold: 6
# ROC_AUC: 0.5902308910560973
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8578811369509044, 0.32]
# Fold: 7
# ROC_AUC: 0.4293156622488956
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.4392764857881137, 0.42]
# Fold: 8
# ROC_AUC: 0.6044427773610068
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8863049095607235, 0.32]
# Fold: 9
# ROC_AUC: 0.5656830874385262
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8087855297157622, 0.32]
# Fold: 10
# ROC_AUC: 0.5793114945403017
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.9328165374677002, 0.23]
# Mean: 0.5795288612208894
# Std deviation: 0.05588445852824646
# CPU times: user 538 ms, sys: 3.99 ms, total: 542 ms
# Wall time: 1.16 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Adaboost

# %%
# %%time

adaboost_base = DecisionTreeClassifier(random_state = 42)

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', AdaBoostClassifier(random_state=42, base_estimator=adaboost_base))
    ])

clf = GridSearchCV(base_clf, parameters_ABC_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Adaboost - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Adaboost - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.49790592783505155
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9020618556701031, 0.09]
# Fold: 2
# ROC_AUC: 0.5224483204134367
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9198966408268734, 0.12]
# Fold: 3
# ROC_AUC: 0.5393014920396767
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.917312661498708, 0.16]
# Fold: 4
# ROC_AUC: 0.5328832208052012
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9689922480620154, 0.1]
# Fold: 5
# ROC_AUC: 0.5257564391097774
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9224806201550387, 0.13]
# Fold: 6
# ROC_AUC: 0.5225473034925399
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9483204134366925, 0.1]
# Fold: 7
# ROC_AUC: 0.3661748770525965
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.5710594315245479, 0.16]
# Fold: 8
# ROC_AUC: 0.4967491872968242
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9612403100775194, 0.03]
# Fold: 9
# ROC_AUC: 0.521255313828457
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9457364341085271, 0.1]
# Fold: 10
# ROC_AUC: 0.49933316662498956
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9664082687338501, 0.03]
# Mean: 0.502435524849855
# Std deviation: 0.047559065697254294
# CPU times: user 7.6 s, sys: 12 ms, total: 7.61 s
# Wall time: 15.9 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Gradient Boost

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', GradientBoostingClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_GBC, scoring='roc_auc', n_jobs=-1)


scores_list = list()

results_dict['Gradient Boost - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Gradient Boost - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.7026417525773195
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8427835051546392, 0.56]
# Fold: 2
# ROC_AUC: 0.6807170542635659
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7364341085271318, 0.62]
# Fold: 3
# ROC_AUC: 0.6766274902058848
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.772609819121447, 0.58]
# Fold: 4
# ROC_AUC: 0.684421105276319
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8527131782945736, 0.52]
# Fold: 5
# ROC_AUC: 0.6449529048928898
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6770025839793282, 0.61]
# Fold: 6
# ROC_AUC: 0.620446778361257
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6925064599483204, 0.55]
# Fold: 7
# ROC_AUC: 0.5467616904226056
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.4806201550387597, 0.61]
# Fold: 8
# ROC_AUC: 0.6850879386513296
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8863049095607235, 0.48]
# Fold: 9
# ROC_AUC: 0.6172793198299575
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7829457364341085, 0.45]
# Fold: 10
# ROC_AUC: 0.5799783279153122
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9664082687338501, 0.19]
# Mean: 0.6438914362396442
# Std deviation: 0.04898697510744994
# CPU times: user 2.68 s, sys: 4.02 ms, total: 2.68 s
# Wall time: 5.54 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## XGBoost

# %%
# %%time


base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', xgb.XGBClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, param_xgb_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['XGBoost - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['XGBoost - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6987757731958764
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8350515463917526, 0.56]
# Fold: 2
# ROC_AUC: 0.7093830749354005
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7312661498708011, 0.69]
# Fold: 3
# ROC_AUC: 0.6907976994248561
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7364341085271318, 0.65]
# Fold: 4
# ROC_AUC: 0.707010085854797
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8656330749354005, 0.55]
# Fold: 5
# ROC_AUC: 0.6972159706593315
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.6847545219638242, 0.71]
# Fold: 6
# ROC_AUC: 0.5881887138451279
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.6925064599483204, 0.48]
# Fold: 7
# ROC_AUC: 0.5886888388763858
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.46770025839793283, 0.71]
# Fold: 8
# ROC_AUC: 0.6760440110027507
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8682170542635659, 0.48]
# Fold: 9
# ROC_AUC: 0.7172626489955821
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7571059431524548, 0.68]
# Fold: 10
# ROC_AUC: 0.5773943485871468
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9612403100775194, 0.19]
# Mean: 0.6650761165377255
# Std deviation: 0.053693865054052076
# CPU times: user 2.17 s, sys: 4 ms, total: 2.18 s
# Wall time: 4.34 s

# %%
with open('base_Over_wo_wofs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
