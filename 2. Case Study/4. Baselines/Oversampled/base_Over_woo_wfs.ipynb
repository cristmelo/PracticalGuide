# %%
# %run auxiliary.ipynb

# %%
all_df = pd.read_csv('wo_outliers.csv') # Original dataa

# %%
results_dict = dict()

# %%
k_fold = StratifiedKFold(10, random_state=42)

X_features = ['CBO','CC','LCOM','WMC']

X = pd.DataFrame(all_df.loc[:, X_features])

y = pd.DataFrame(all_df.loc[:, 'will_change'])
X = X.rename(columns={'CBO':'f0', 'CC':'f1', 'LCOM':'f2', 'WMC':'f3'})

# %%
X.head()
# Out:
#          f0        f1   f2        f3
# 0  0.000000  0.004098  0.0  0.017857
# 1  0.000000  0.004098  0.0  0.017857
# 2  0.129630  0.018443  0.0  0.071429
# 3  0.006173  0.014344  0.0  0.035714
# 4  0.006173  0.004098  0.0  0.017857

# %%
parameters_svc_linear = {
        'clf__kernel':['linear'],
    'clf__max_iter':[10000],
    }

parameters_svc_rbf = {
        'clf__kernel':['rbf'],
    }

parameters_dtc_grid = {
    'clf__criterion':['gini'], 
}

parameters_rfc_grid = { 
    'clf__criterion' :['gini'],
}

parameters_ABC_grid = {
    'clf__base_estimator__criterion' : ["gini"],
}


parameters_knn_grid = {'clf__n_neighbors': [5]}


parameters_lr_grid = [{
                        'clf__penalty':['l2'],
                        }]

parameters_GBC = {
    "clf__loss":["deviance"],
    }


param_xgb_grid = {
           'clf__clf__random_state': [42] #ensemble xgboost with multiple seeds may reduce variance
             }

param_lgm_grid = {
    "clf__random_state":[42]
}

# %% [markdown]
# # SMOTE

# %%
sampler = SMOTE(random_state=42)

# %% [markdown]
# ## Light GBM

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', lbm.LGBMClassifier())
    ])


clf = GridSearchCV(base_clf, param_lgm_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Light GBM - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Light GBM - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6269420234937477
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.978021978021978, 0.28]
# Fold: 2
# ROC_AUC: 0.6766767715043577
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9395604395604396, 0.41]
# Fold: 3
# ROC_AUC: 0.5890962485790072
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9368131868131868, 0.24]
# Fold: 4
# ROC_AUC: 0.5924592648730579
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.978021978021978, 0.21]
# Fold: 5
# ROC_AUC: 0.580854490337249
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9203296703296703, 0.24]
# Fold: 6
# ROC_AUC: 0.5367563471011748
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9010989010989011, 0.17]
# Fold: 7
# ROC_AUC: 0.7079386131110269
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8296703296703297, 0.59]
# Fold: 8
# ROC_AUC: 0.7183687524596616
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9724517906336089, 0.46]
# Fold: 9
# ROC_AUC: 0.6675521448248721
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.977961432506887, 0.36]
# Fold: 10
# ROC_AUC: 0.5178079496261314
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#     ...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9641873278236914, 0.07]
# Mean: 0.6214452605910286
# Std deviation: 0.06597651379690092
# Wall time: 10 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Logistic Regression

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', LogisticRegression(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_lr_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Logistic Regression - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Logistic Regression - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6617089806744979
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8406593406593407, 0.48]
# Fold: 2
# ROC_AUC: 0.7259378552482001
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7967032967032966, 0.66]
# Fold: 3
# ROC_AUC: 0.7100701023114816
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7994505494505495, 0.62]
# Fold: 4
# ROC_AUC: 0.6995547555892383
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8818681318681318, 0.52]
# Fold: 5
# ROC_AUC: 0.571523304281925
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7637362637362637, 0.38]
# Fold: 6
# ROC_AUC: 0.5818965517241379
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.75, 0.41]
# Fold: 7
# ROC_AUC: 0.7372110647972717
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6813186813186813, 0.79]
# Fold: 8
# ROC_AUC: 0.7498032270759544
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8567493112947658, 0.64]
# Fold: 9
# ROC_AUC: 0.7429161747343566
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8429752066115702, 0.64]
# Fold: 10
# ROC_AUC: 0.7032172373081464
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9421487603305785, 0.46]
# Mean: 0.688383925374521
# Std deviation: 0.06087947690273074
# Wall time: 1.28 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - Linear

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_linear, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM Linear - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM Linear - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6292156119742327
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8791208791208791, 0.38]
# Fold: 2
# ROC_AUC: 0.7602785145888594
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8653846153846154, 0.66]
# Fold: 3
# ROC_AUC: 0.7175539977264116
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8489010989010989, 0.59]
# Fold: 4
# ROC_AUC: 0.7180276619931792
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9532967032967034, 0.48]
# Fold: 5
# ROC_AUC: 0.5803808260704812
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8159340659340659, 0.34]
# Fold: 6
# ROC_AUC: 0.5707654414550967
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7967032967032966, 0.34]
# Fold: 7
# ROC_AUC: 0.7570575975748389
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7554945054945055, 0.76]
# Fold: 8
# ROC_AUC: 0.788370720188902
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9338842975206612, 0.64]
# Fold: 9
# ROC_AUC: 0.6757182211727666
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9228650137741047, 0.43]
# Fold: 10
# ROC_AUC: 0.6867866981503346
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9807162534435262, 0.39]
# Mean: 0.6884155290895102
# Std deviation: 0.07125625329047276
# Wall time: 16.7 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - RBF

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_rbf, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM RBF - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM RBF - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6305892383478591
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8818681318681318, 0.38]
# Fold: 2
# ROC_AUC: 0.758904888215233
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8626373626373627, 0.66]
# Fold: 3
# ROC_AUC: 0.7203012504736642
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8543956043956044, 0.59]
# Fold: 4
# ROC_AUC: 0.6711822660098522
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9285714285714286, 0.41]
# Fold: 5
# ROC_AUC: 0.6058639636225843
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8324175824175825, 0.38]
# Fold: 6
# ROC_AUC: 0.5735126942023494
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8021978021978022, 0.34]
# Fold: 7
# ROC_AUC: 0.7598048503220917
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.760989010989011, 0.76]
# Fold: 8
# ROC_AUC: 0.7553128689492326
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8677685950413223, 0.64]
# Fold: 9
# ROC_AUC: 0.7031680440771348
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.90633608815427, 0.5]
# Fold: 10
# ROC_AUC: 0.6290830381739472
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9724517906336089, 0.29]
# Mean: 0.6807723102393949
# Std deviation: 0.06509164244413698
# Wall time: 26.1 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Decision Tree

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', DecisionTreeClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_dtc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Decision Tree - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Decision Tree - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5945907540735127
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9478021978021978, 0.24]
# Fold: 2
# ROC_AUC: 0.6222053808260705
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9340659340659341, 0.31]
# Fold: 3
# ROC_AUC: 0.581470253884047
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9560439560439561, 0.21]
# Fold: 4
# ROC_AUC: 0.5656025009473286
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9587912087912088, 0.17]
# Fold: 5
# ROC_AUC: 0.6035903751420993
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9313186813186813, 0.28]
# Fold: 6
# ROC_AUC: 0.5187571049640015
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9340659340659341, 0.1]
# Fold: 7
# ROC_AUC: 0.6522356953391436
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.7527472527472527, 0.55]
# Fold: 8
# ROC_AUC: 0.6867375049193232
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9449035812672176, 0.43]
# Fold: 9
# ROC_AUC: 0.6194411648957103
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.953168044077135, 0.29]
# Fold: 10
# ROC_AUC: 0.537042502951594
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#       ...        min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9669421487603306, 0.11]
# Mean: 0.5981673237942831
# Std deviation: 0.048189374381040886
# Wall time: 1.21 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Random Forest

# %%
# %%time


base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', RandomForestClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_rfc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Random Forest - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Random Forest - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6194581280788177
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9285714285714286, 0.31]
# Fold: 2
# ROC_AUC: 0.631205001894657
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9175824175824175, 0.34]
# Fold: 3
# ROC_AUC: 0.5863489958317545
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9313186813186813, 0.24]
# Fold: 4
# ROC_AUC: 0.5297461159530125
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9560439560439561, 0.1]
# Fold: 5
# ROC_AUC: 0.6084691170898068
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9065934065934066, 0.31]
# Fold: 6
# ROC_AUC: 0.4644278135657446
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8598901098901099, 0.07]
# Fold: 7
# ROC_AUC: 0.6377415687760515
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7582417582417582, 0.52]
# Fold: 8
# ROC_AUC: 0.693624557260921
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9586776859504132, 0.43]
# Fold: 9
# ROC_AUC: 0.6606650924832743
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9641873278236914, 0.36]
# Fold: 10
# ROC_AUC: 0.4999508067689886
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#       ...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9641873278236914, 0.04]
# Mean: 0.5931637197703028
# Std deviation: 0.06952596902113879
# Wall time: 3.2 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## KNN

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', KNeighborsClassifier())
    ])

clf = GridSearchCV(base_clf, parameters_knn_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['KNN - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['KNN - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6209738537324745
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8626373626373627, 0.38]
# Fold: 2
# ROC_AUC: 0.571523304281925
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7637362637362637, 0.38]
# Fold: 3
# ROC_AUC: 0.5314039408866995
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8214285714285714, 0.24]
# Fold: 4
# ROC_AUC: 0.5864910951117848
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8626373626373627, 0.31]
# Fold: 5
# ROC_AUC: 0.5783914361500568
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7774725274725275, 0.38]
# Fold: 6
# ROC_AUC: 0.44685486926866236
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.6868131868131868, 0.21]
# Fold: 7
# ROC_AUC: 0.5959170140204623
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.6401098901098901, 0.55]
# Fold: 8
# ROC_AUC: 0.682556080283353
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.9008264462809917, 0.46]
# Fold: 9
# ROC_AUC: 0.7319460842188115
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8567493112947658, 0.61]
# Fold: 10
# ROC_AUC: 0.5933195592286501
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.9366391184573003, 0.25]
# Mean: 0.593937723718288
# Std deviation: 0.07346982940882642
# Wall time: 1.66 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Adaboost

# %%
# %%time

adaboost_base = DecisionTreeClassifier(random_state = 42)

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', AdaBoostClassifier(random_state=42, base_estimator=adaboost_base))
    ])

clf = GridSearchCV(base_clf, parameters_ABC_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Adaboost - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Adaboost - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6145793861311103
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9532967032967034, 0.28]
# Fold: 2
# ROC_AUC: 0.6456991284577492
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9120879120879121, 0.38]
# Fold: 3
# ROC_AUC: 0.5836017430845017
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9258241758241759, 0.24]
# Fold: 4
# ROC_AUC: 0.5497347480106102
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9615384615384616, 0.14]
# Fold: 5
# ROC_AUC: 0.5712391057218644
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9010989010989011, 0.24]
# Fold: 6
# ROC_AUC: 0.4987684729064039
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9285714285714286, 0.07]
# Fold: 7
# ROC_AUC: 0.6246210685865858
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.7664835164835165, 0.48]
# Fold: 8
# ROC_AUC: 0.69637937819756
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9641873278236914, 0.43]
# Fold: 9
# ROC_AUC: 0.6798996458087366
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9669421487603306, 0.39]
# Fold: 10
# ROC_AUC: 0.5054604486422669
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClass...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9752066115702479, 0.04]
# Mean: 0.5969983125547389
# Std deviation: 0.06426370577763728
# Wall time: 13.5 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Gradient Boost

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', GradientBoostingClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_GBC, scoring='roc_auc', n_jobs=-1)


scores_list = list()

results_dict['Gradient Boost - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Gradient Boost - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6905551345206519
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8983516483516484, 0.48]
# Fold: 2
# ROC_AUC: 0.7244221295945434
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8626373626373627, 0.59]
# Fold: 3
# ROC_AUC: 0.6348522167487685
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8214285714285714, 0.45]
# Fold: 4
# ROC_AUC: 0.6870500189465707
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9258241758241759, 0.45]
# Fold: 5
# ROC_AUC: 0.5921276998863206
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.804945054945055, 0.38]
# Fold: 6
# ROC_AUC: 0.592885562713149
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.771978021978022, 0.41]
# Fold: 7
# ROC_AUC: 0.6874763167866615
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7197802197802198, 0.66]
# Fold: 8
# ROC_AUC: 0.7375541125541125
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9393939393939394, 0.54]
# Fold: 9
# ROC_AUC: 0.6537288469106651
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9146005509641874, 0.39]
# Fold: 10
# ROC_AUC: 0.5480617866981504
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               lear...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9889807162534435, 0.11]
# Mean: 0.6548713825359594
# Std deviation: 0.05885149999376108
# Wall time: 5.64 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## XGBoost

# %%
# %%time


base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', xgb.XGBClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, param_xgb_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['XGBoost - SMOTE'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['XGBoost - SMOTE'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6588196286472148
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9038461538461539, 0.41]
# Fold: 2
# ROC_AUC: 0.7279272451686245
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8351648351648352, 0.62]
# Fold: 3
# ROC_AUC: 0.6348522167487685
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8214285714285714, 0.45]
# Fold: 4
# ROC_AUC: 0.7319060250094732
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9120879120879121, 0.55]
# Fold: 5
# ROC_AUC: 0.5907540735126943
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8021978021978022, 0.38]
# Fold: 6
# ROC_AUC: 0.5425350511557409
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7747252747252747, 0.31]
# Fold: 7
# ROC_AUC: 0.6592459264873057
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.6978021978021978, 0.62]
# Fold: 8
# ROC_AUC: 0.749901613537977
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.928374655647383, 0.57]
# Fold: 9
# ROC_AUC: 0.682556080283353
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9008264462809917, 0.46]
# Fold: 10
# ROC_AUC: 0.5494391971664699
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1,
#    out_step='deprecated', random_state=42, ratio=None,
#    sampling_strategy='auto', svm_estimator='deprecated')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsam...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9917355371900827, 0.11]
# Mean: 0.6527937057717622
# Std deviation: 0.07021925216734463
# Wall time: 7.14 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # ADASYN

# %%
sampler = ADASYN(random_state=42)

# %% [markdown]
# ## Light GBM

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', lbm.LGBMClassifier())
    ])


clf = GridSearchCV(base_clf, param_lgm_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Light GBM - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Light GBM - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.624194770746495
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9725274725274725, 0.28]
# Fold: 2
# ROC_AUC: 0.627084122773778
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9093406593406593, 0.34]
# Fold: 3
# ROC_AUC: 0.59184350132626
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9423076923076923, 0.24]
# Fold: 4
# ROC_AUC: 0.6097006441834029
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.978021978021978, 0.24]
# Fold: 5
# ROC_AUC: 0.5836017430845017
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9258241758241759, 0.24]
# Fold: 6
# ROC_AUC: 0.5395035998484274
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9065934065934066, 0.17]
# Fold: 7
# ROC_AUC: 0.6961917392951875
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8406593406593407, 0.55]
# Fold: 8
# ROC_AUC: 0.6798996458087366
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9669421487603306, 0.39]
# Fold: 9
# ROC_AUC: 0.662042502951594
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9669421487603306, 0.36]
# Fold: 10
# ROC_AUC: 0.5178079496261314
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_c...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9641873278236914, 0.07]
# Mean: 0.6131870219644513
# Std deviation: 0.05469087566541502
# Wall time: 4.72 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Logistic Regression

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', LogisticRegression(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_lr_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Logistic Regression - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Logistic Regression - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6514778325123152
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7857142857142857, 0.52]
# Fold: 2
# ROC_AUC: 0.7302008336491095
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7362637362637363, 0.72]
# Fold: 3
# ROC_AUC: 0.6812239484653277
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7417582417582418, 0.62]
# Fold: 4
# ROC_AUC: 0.6824554755589238
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8131868131868132, 0.55]
# Fold: 5
# ROC_AUC: 0.5626657824933687
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7115384615384616, 0.41]
# Fold: 6
# ROC_AUC: 0.5579291398256916
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6675824175824175, 0.45]
# Fold: 7
# ROC_AUC: 0.716606669192876
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6401098901098901, 0.79]
# Fold: 8
# ROC_AUC: 0.7359799291617474
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7933884297520661, 0.68]
# Fold: 9
# ROC_AUC: 0.7374065328610783
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8319559228650137, 0.64]
# Fold: 10
# ROC_AUC: 0.7100550964187328
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9201101928374655, 0.5]
# Mean: 0.6766001240139171
# Std deviation: 0.06369207691379614
# Wall time: 1.13 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - Linear

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_linear, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM Linear - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM Linear - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6423361121636983
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8708791208791209, 0.41]
# Fold: 2
# ROC_AUC: 0.743794998105343
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8324175824175825, 0.66]
# Fold: 3
# ROC_AUC: 0.7065649867374005
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8269230769230769, 0.59]
# Fold: 4
# ROC_AUC: 0.7091701402046229
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9010989010989011, 0.52]
# Fold: 5
# ROC_AUC: 0.5707654414550967
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7967032967032966, 0.34]
# Fold: 6
# ROC_AUC: 0.5901383099658961
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7664835164835165, 0.41]
# Fold: 7
# ROC_AUC: 0.7474422129594543
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7362637362637363, 0.76]
# Fold: 8
# ROC_AUC: 0.7594451003541912
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8760330578512396, 0.64]
# Fold: 9
# ROC_AUC: 0.6688311688311688
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9090909090909091, 0.43]
# Fold: 10
# ROC_AUC: 0.662042502951594
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9669421487603306, 0.36]
# Mean: 0.6800530973728465
# Std deviation: 0.0619349984275243
# Wall time: 16.6 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - RBF

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_rbf, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM RBF - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM RBF - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6395888594164456
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8653846153846154, 0.41]
# Fold: 2
# ROC_AUC: 0.7300587343690792
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.804945054945055, 0.66]
# Fold: 3
# ROC_AUC: 0.7038177339901478
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8214285714285714, 0.59]
# Fold: 4
# ROC_AUC: 0.6047745358090185
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.6923076923076923, 0.52]
# Fold: 5
# ROC_AUC: 0.5907540735126943
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8021978021978022, 0.38]
# Fold: 6
# ROC_AUC: 0.5915119363395225
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7692307692307693, 0.41]
# Fold: 7
# ROC_AUC: 0.7474422129594543
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7362637362637363, 0.76]
# Fold: 8
# ROC_AUC: 0.6189492325855963
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.5950413223140496, 0.64]
# Fold: 9
# ROC_AUC: 0.7278630460448642
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8842975206611571, 0.57]
# Fold: 10
# ROC_AUC: 0.6661255411255411
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9393939393939394, 0.39]
# Mean: 0.6620885906152363
# Std deviation: 0.058061087748208846
# Wall time: 27.8 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Decision Tree

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', DecisionTreeClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_dtc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Decision Tree - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Decision Tree - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5781072375899963
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9148351648351648, 0.24]
# Fold: 2
# ROC_AUC: 0.6070954907161803
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9038461538461539, 0.31]
# Fold: 3
# ROC_AUC: 0.5269988632057597
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9505494505494505, 0.1]
# Fold: 4
# ROC_AUC: 0.5628552482000758
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9532967032967034, 0.17]
# Fold: 5
# ROC_AUC: 0.5739863584691172
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9065934065934066, 0.24]
# Fold: 6
# ROC_AUC: 0.5146362258431224
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9258241758241759, 0.1]
# Fold: 7
# ROC_AUC: 0.6708507010231148
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.7554945054945055, 0.59]
# Fold: 8
# ROC_AUC: 0.6894923258559622
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9504132231404959, 0.43]
# Fold: 9
# ROC_AUC: 0.6331660763478946
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9449035812672176, 0.32]
# Fold: 10
# ROC_AUC: 0.5219401810310901
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9724517906336089, 0.07]
# Mean: 0.5879128708282313
# Std deviation: 0.05827800300471609
# Wall time: 1.26 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Random Forest

# %%
# %%time


base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', RandomForestClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_rfc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Random Forest - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Random Forest - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.591227737779462
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9065934065934066, 0.28]
# Fold: 2
# ROC_AUC: 0.590611974232664
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8708791208791209, 0.31]
# Fold: 3
# ROC_AUC: 0.6167108753315651
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9230769230769231, 0.31]
# Fold: 4
# ROC_AUC: 0.6159530125047367
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9560439560439561, 0.28]
# Fold: 5
# ROC_AUC: 0.5616237211064797
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8818681318681318, 0.24]
# Fold: 6
# ROC_AUC: 0.48365858279651386
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8983516483516484, 0.07]
# Fold: 7
# ROC_AUC: 0.6384994316028798
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7252747252747253, 0.55]
# Fold: 8
# ROC_AUC: 0.6881149153876427
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9476584022038568, 0.43]
# Fold: 9
# ROC_AUC: 0.6276564344746163
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9338842975206612, 0.32]
# Fold: 10
# ROC_AUC: 0.5164305391578119
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9614325068870524, 0.07]
# Mean: 0.5930487224374372
# Std deviation: 0.05676167617021843
# Wall time: 3.03 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## KNN

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', KNeighborsClassifier())
    ])

clf = GridSearchCV(base_clf, parameters_knn_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['KNN - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['KNN - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6168529746115953
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8543956043956044, 0.38]
# Fold: 2
# ROC_AUC: 0.5660287987874195
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7527472527472527, 0.38]
# Fold: 3
# ROC_AUC: 0.5245358090185677
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8076923076923077, 0.24]
# Fold: 4
# ROC_AUC: 0.5892383478590375
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8681318681318682, 0.31]
# Fold: 5
# ROC_AUC: 0.5625236832133383
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7802197802197802, 0.34]
# Fold: 6
# ROC_AUC: 0.4413603637741569
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.6758241758241759, 0.21]
# Fold: 7
# ROC_AUC: 0.6166635089048882
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.6126373626373627, 0.62]
# Fold: 8
# ROC_AUC: 0.6619441164895711
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8953168044077136, 0.43]
# Fold: 9
# ROC_AUC: 0.7704151908697363
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8622589531680441, 0.68]
# Fold: 10
# ROC_AUC: 0.5713301849665485
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.928374655647383, 0.21]
# Mean: 0.5920892978494858
# Std deviation: 0.0819585142794257
# Wall time: 1.59 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Adaboost

# %%
# %%time

adaboost_base = DecisionTreeClassifier(random_state = 42)

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', AdaBoostClassifier(random_state=42, base_estimator=adaboost_base))
    ])

clf = GridSearchCV(base_clf, parameters_ABC_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Adaboost - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Adaboost - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6070954907161803
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9038461538461539, 0.31]
# Fold: 2
# ROC_AUC: 0.6029746115953013
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.8956043956043956, 0.31]
# Fold: 3
# ROC_AUC: 0.5608658582796513
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9148351648351648, 0.21]
# Fold: 4
# ROC_AUC: 0.5628552482000758
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9532967032967034, 0.17]
# Fold: 5
# ROC_AUC: 0.5643709738537325
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.8873626373626373, 0.24]
# Fold: 6
# ROC_AUC: 0.5056366047745358
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9423076923076923, 0.07]
# Fold: 7
# ROC_AUC: 0.6404888215233042
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.7637362637362637, 0.52]
# Fold: 8
# ROC_AUC: 0.6950019677292405
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9614325068870524, 0.43]
# Fold: 9
# ROC_AUC: 0.7045946477764661
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9449035812672176, 0.46]
# Fold: 10
# ROC_AUC: 0.5068378591105864
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_lea...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.977961432506887, 0.04]
# Mean: 0.5950722083559075
# Std deviation: 0.06571559774832827
# Wall time: 14.2 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Gradient Boost

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', GradientBoostingClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_GBC, scoring='roc_auc', n_jobs=-1)


scores_list = list()

results_dict['Gradient Boost - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Gradient Boost - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6960496400151572
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9093406593406593, 0.48]
# Fold: 2
# ROC_AUC: 0.7183118605532398
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8159340659340659, 0.62]
# Fold: 3
# ROC_AUC: 0.6672034861690035
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8516483516483516, 0.48]
# Fold: 4
# ROC_AUC: 0.7001705191360363
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9175824175824175, 0.48]
# Fold: 5
# ROC_AUC: 0.5432929139825692
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7417582417582418, 0.34]
# Fold: 6
# ROC_AUC: 0.5377984084880637
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7307692307692307, 0.34]
# Fold: 7
# ROC_AUC: 0.6592459264873057
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6978021978021978, 0.62]
# Fold: 8
# ROC_AUC: 0.7443919716646991
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9173553719008265, 0.57]
# Fold: 9
# ROC_AUC: 0.71413813459268
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8925619834710744, 0.54]
# Fold: 10
# ROC_AUC: 0.5302046438410074
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9889807162534435, 0.07]
# Mean: 0.6510807504929763
# Std deviation: 0.07811785892484899
# Wall time: 6.46 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## XGBoost

# %%
# %%time


base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', xgb.XGBClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, param_xgb_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['XGBoost - ADASYN'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['XGBoost - ADASYN'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6746873815839334
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9010989010989011, 0.45]
# Fold: 2
# ROC_AUC: 0.7065649867374005
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8269230769230769, 0.59]
# Fold: 3
# ROC_AUC: 0.6996968548692687
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8131868131868132, 0.59]
# Fold: 4
# ROC_AUC: 0.7001705191360363
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9175824175824175, 0.48]
# Fold: 5
# ROC_AUC: 0.606763925729443
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7307692307692307, 0.48]
# Fold: 6
# ROC_AUC: 0.5281830238726791
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7115384615384616, 0.34]
# Fold: 7
# ROC_AUC: 0.6619931792345585
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7032967032967034, 0.62]
# Fold: 8
# ROC_AUC: 0.762249114521842
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9173553719008265, 0.61]
# Fold: 9
# ROC_AUC: 0.7264856355765447
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8815426997245179, 0.57]
# Fold: 10
# ROC_AUC: 0.5288272333726879
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', ADASYN(n_jobs=1, n_neighbors=5, random_state=42, ratio=None,
#     sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9862258953168044, 0.07]
# Mean: 0.6595621854634394
# Std deviation: 0.07607029293480189
# Wall time: 7.75 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Random OverSampler

# %%
sampler = RandomOverSampler(random_state=42)

# %% [markdown]
# ## Light GBM

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', lbm.LGBMClassifier())
    ])


clf = GridSearchCV(base_clf, param_lgm_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Light GBM - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Light GBM - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6002273588480485
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8901098901098901, 0.31]
# Fold: 2
# ROC_AUC: 0.6348522167487685
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8214285714285714, 0.45]
# Fold: 3
# ROC_AUC: 0.5997536945812807
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.7857142857142857, 0.41]
# Fold: 4
# ROC_AUC: 0.5753599848427435
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9093406593406593, 0.24]
# Fold: 5
# ROC_AUC: 0.5825123152709359
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.7857142857142857, 0.38]
# Fold: 6
# ROC_AUC: 0.526525198938992
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8461538461538461, 0.21]
# Fold: 7
# ROC_AUC: 0.6186528988253126
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.6510989010989011, 0.59]
# Fold: 8
# ROC_AUC: 0.6248524203069659
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8925619834710744, 0.36]
# Fold: 9
# ROC_AUC: 0.6962809917355371
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.8925619834710744, 0.5]
# Fold: 10
# ROC_AUC: 0.5094942935852027
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samp...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))])
# [Confusion Matrix]: [0.9118457300275482, 0.11]
# Mean: 0.5968511373683787
# Std deviation: 0.05084684607720441
# Wall time: 3.34 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Logistic Regression

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', LogisticRegression(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_lr_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Logistic Regression - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Logistic Regression - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.644467601364153
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8406593406593407, 0.45]
# Fold: 2
# ROC_AUC: 0.7486737400530504
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8076923076923077, 0.69]
# Fold: 3
# ROC_AUC: 0.6928287230011368
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7994505494505495, 0.59]
# Fold: 4
# ROC_AUC: 0.7064228874573701
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8956043956043956, 0.52]
# Fold: 5
# ROC_AUC: 0.5597764304660856
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7747252747252747, 0.34]
# Fold: 6
# ROC_AUC: 0.5832701780977643
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7527472527472527, 0.41]
# Fold: 7
# ROC_AUC: 0.7399583175445245
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6868131868131868, 0.79]
# Fold: 8
# ROC_AUC: 0.7690869736324283
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8953168044077136, 0.64]
# Fold: 9
# ROC_AUC: 0.7484258166076347
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8539944903581267, 0.64]
# Fold: 10
# ROC_AUC: 0.7032172373081464
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9421487603305785, 0.46]
# Mean: 0.6896127905532294
# Std deviation: 0.06817646803408527
# Wall time: 553 ms

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - Linear

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_linear, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM Linear - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM Linear - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6278419856006063
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8763736263736264, 0.38]
# Fold: 2
# ROC_AUC: 0.7630257673361122
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8708791208791209, 0.66]
# Fold: 3
# ROC_AUC: 0.7203012504736642
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8543956043956044, 0.59]
# Fold: 4
# ROC_AUC: 0.7194012883668056
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9560439560439561, 0.48]
# Fold: 5
# ROC_AUC: 0.5845017051913604
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8241758241758241, 0.34]
# Fold: 6
# ROC_AUC: 0.5776335733232285
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8104395604395604, 0.34]
# Fold: 7
# ROC_AUC: 0.7453107237589995
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7664835164835165, 0.72]
# Fold: 8
# ROC_AUC: 0.7925029515938606
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9421487603305785, 0.64]
# Fold: 9
# ROC_AUC: 0.6592384887839433
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9256198347107438, 0.39]
# Fold: 10
# ROC_AUC: 0.6867866981503346
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9807162534435262, 0.39]
# Mean: 0.6876544432578915
# Std deviation: 0.07014470600380456
# Wall time: 15.2 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## SVM - RBF

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', svm.SVC(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_svc_rbf, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['SVM RBF - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['SVM RBF - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6305892383478591
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8818681318681318, 0.38]
# Fold: 2
# ROC_AUC: 0.7630257673361122
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8708791208791209, 0.66]
# Fold: 3
# ROC_AUC: 0.7271693823417962
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8681318681318682, 0.59]
# Fold: 4
# ROC_AUC: 0.6876657824933687
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9615384615384616, 0.41]
# Fold: 5
# ROC_AUC: 0.5968643425539977
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8489010989010989, 0.34]
# Fold: 6
# ROC_AUC: 0.5790071996968549
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.8131868131868132, 0.34]
# Fold: 7
# ROC_AUC: 0.7625521030693443
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.7664835164835165, 0.76]
# Fold: 8
# ROC_AUC: 0.7636265249901613
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9201101928374655, 0.61]
# Fold: 9
# ROC_AUC: 0.6715859897678079
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9146005509641874, 0.43]
# Fold: 10
# ROC_AUC: 0.6469401810310901
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=42,
#   shrinking=True, tol=0.001, verbose=False))])
# [Confusion Matrix]: [0.9724517906336089, 0.32]
# Mean: 0.6829026511628393
# Std deviation: 0.0660433480953245
# Wall time: 26.1 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Decision Tree

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', DecisionTreeClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_dtc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Decision Tree - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Decision Tree - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5739863584691172
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9065934065934066, 0.24]
# Fold: 2
# ROC_AUC: 0.5996115953012505
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8543956043956044, 0.34]
# Fold: 3
# ROC_AUC: 0.5292724516862447
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8516483516483516, 0.21]
# Fold: 4
# ROC_AUC: 0.5443823417961349
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8818681318681318, 0.21]
# Fold: 5
# ROC_AUC: 0.5829859795377037
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8901098901098901, 0.28]
# Fold: 6
# ROC_AUC: 0.5147783251231528
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8571428571428571, 0.17]
# Fold: 7
# ROC_AUC: 0.5614342553997727
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.6401098901098901, 0.48]
# Fold: 8
# ROC_AUC: 0.6262298307752854
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8953168044077136, 0.36]
# Fold: 9
# ROC_AUC: 0.5630165289256198
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.8760330578512396, 0.25]
# Fold: 10
# ROC_AUC: 0.49439197166469895
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'))])
# [Confusion Matrix]: [0.9173553719008265, 0.07]
# Mean: 0.5590089638678981
# Std deviation: 0.03770714015725243
# Wall time: 673 ms

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Random Forest

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', RandomForestClassifier(random_state=42))
    ])

clf = GridSearchCV(base_clf, parameters_rfc_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Random Forest - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Random Forest - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5857332322849564
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8956043956043956, 0.28]
# Fold: 2
# ROC_AUC: 0.6064797271693824
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8681318681318682, 0.34]
# Fold: 3
# ROC_AUC: 0.5506347101174688
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8598901098901099, 0.24]
# Fold: 4
# ROC_AUC: 0.5036472148541113
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9038461538461539, 0.1]
# Fold: 5
# ROC_AUC: 0.5616237211064797
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8818681318681318, 0.24]
# Fold: 6
# ROC_AUC: 0.5167677150435772
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8956043956043956, 0.14]
# Fold: 7
# ROC_AUC: 0.5441928760894278
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6401098901098901, 0.45]
# Fold: 8
# ROC_AUC: 0.6660763478945297
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9035812672176309, 0.43]
# Fold: 9
# ROC_AUC: 0.609750098386462
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8980716253443526, 0.32]
# Fold: 10
# ROC_AUC: 0.4847992916174735
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impu...rs='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9338842975206612, 0.04]
# Mean: 0.5629704934563868
# Std deviation: 0.05244198082505733
# Wall time: 2.38 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## KNN

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', KNeighborsClassifier())
    ])

clf = GridSearchCV(base_clf, parameters_knn_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['KNN - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['KNN - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.594732853353543
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8791208791208791, 0.31]
# Fold: 2
# ROC_AUC: 0.5817544524441076
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8186813186813187, 0.34]
# Fold: 3
# ROC_AUC: 0.5423929518757105
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8434065934065934, 0.24]
# Fold: 4
# ROC_AUC: 0.562997347480106
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8846153846153846, 0.24]
# Fold: 5
# ROC_AUC: 0.5307881773399015
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7857142857142857, 0.28]
# Fold: 6
# ROC_AUC: 0.46333838575217884
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.7197802197802198, 0.21]
# Fold: 7
# ROC_AUC: 0.6021693823417962
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.6181318681318682, 0.59]
# Fold: 8
# ROC_AUC: 0.650974025974026
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.9090909090909091, 0.39]
# Fold: 9
# ROC_AUC: 0.6646497441951988
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.8650137741046832, 0.46]
# Fold: 10
# ROC_AUC: 0.5713301849665485
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform'))])
# [Confusion Matrix]: [0.928374655647383, 0.21]
# Mean: 0.5765127505723117
# Std deviation: 0.05532014166357778
# Wall time: 1.27 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Adaboost

# %%
# %%time

adaboost_base = DecisionTreeClassifier(random_state = 42)

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', AdaBoostClassifier(random_state=42, base_estimator=adaboost_base))
    ])

clf = GridSearchCV(base_clf, parameters_ABC_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['Adaboost - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Adaboost - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.5608658582796513
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9148351648351648, 0.21]
# Fold: 2
# ROC_AUC: 0.5843596059113301
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.8928571428571429, 0.28]
# Fold: 3
# ROC_AUC: 0.5430087154225085
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.8791208791208791, 0.21]
# Fold: 4
# ROC_AUC: 0.5263830996589617
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9148351648351648, 0.14]
# Fold: 5
# ROC_AUC: 0.5698654793482381
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.8983516483516484, 0.24]
# Fold: 6
# ROC_AUC: 0.5250094732853353
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9120879120879121, 0.14]
# Fold: 7
# ROC_AUC: 0.5483137552103069
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.6483516483516484, 0.45]
# Fold: 8
# ROC_AUC: 0.6317394726485636
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.90633608815427, 0.36]
# Fold: 9
# ROC_AUC: 0.5726584022038568
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.8953168044077136, 0.25]
# Fold: 10
# ROC_AUC: 0.46831955922865015
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=...e=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=42))])
# [Confusion Matrix]: [0.9366391184573003, 0.0]
# Mean: 0.5530523421197403
# Std deviation: 0.04086632307015079
# Wall time: 6.79 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Gradient Boost

# %%
# %%time

base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', GradientBoostingClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, parameters_GBC, scoring='roc_auc', n_jobs=-1)


scores_list = list()

results_dict['Gradient Boost - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['Gradient Boost - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6044903372489578
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8296703296703297, 0.38]
# Fold: 2
# ROC_AUC: 0.7370689655172414
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.75, 0.72]
# Fold: 3
# ROC_AUC: 0.6156214475179993
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.782967032967033, 0.45]
# Fold: 4
# ROC_AUC: 0.672697991663509
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8626373626373627, 0.48]
# Fold: 5
# ROC_AUC: 0.6246210685865858
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7664835164835165, 0.48]
# Fold: 6
# ROC_AUC: 0.606763925729443
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.7307692307692307, 0.48]
# Fold: 7
# ROC_AUC: 0.6511462675255779
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.6126373626373627, 0.69]
# Fold: 8
# ROC_AUC: 0.755362062180244
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9035812672176309, 0.61]
# Fold: 9
# ROC_AUC: 0.7593959071231798
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.8402203856749312, 0.68]
# Fold: 10
# ROC_AUC: 0.5535222353404171
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_le...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False))])
# [Confusion Matrix]: [0.9641873278236914, 0.14]
# Mean: 0.6580690208433155
# Std deviation: 0.06751997986204891
# Wall time: 5.07 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## XGBoost

# %%
# %%time


base_clf = Pipeline([
        ('sampling', sampler),
        ('clf', xgb.XGBClassifier(random_state=42))
    ])


clf = GridSearchCV(base_clf, param_xgb_grid, scoring='roc_auc', n_jobs=-1)

scores_list = list()

results_dict['XGBoost - RandomOverSampler'] = dict()

for k, (train, test) in enumerate(k_fold.split(X, y)):
    clf.fit(X.iloc[train], y.iloc[train])
    
    print('Fold: ' + str(k + 1))
    
    print('ROC_AUC: ' + str(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test]))))
    print('Estimator and parameters: ' + str(clf.get_params()['estimator']))
    cnf_matrix = confusion_matrix(y.iloc[test], clf.predict(X.iloc[test]))
    cnf_matrix = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
    print('[Confusion Matrix]: [' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']')
    
    results_dict['XGBoost - RandomOverSampler'][k + 1] = [get_scores(y.iloc[test], clf.predict(X.iloc[test])), 
                                                             str(clf.get_params()['estimator']),
                                                             '[' + str(cnf_matrix[0][0]) + ', ' + str(round(cnf_matrix[1][1],2)) + ']']
    
    scores_list.append(roc_auc_score(y.iloc[test], clf.predict(X.iloc[test])))
    
print('Mean: ' + str(np.mean(scores_list)))
print('Std deviation: ' + str(np.std(scores_list)))
# Out:
# Fold: 1
# ROC_AUC: 0.6458412277377794
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8434065934065934, 0.45]
# Fold: 2
# ROC_AUC: 0.7343217127699886
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7445054945054945, 0.72]
# Fold: 3
# ROC_AUC: 0.6115005683971201
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7747252747252747, 0.45]
# Fold: 4
# ROC_AUC: 0.6699507389162562
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8571428571428571, 0.48]
# Fold: 5
# ROC_AUC: 0.6032588101553619
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.7582417582417582, 0.45]
# Fold: 6
# ROC_AUC: 0.6571144372868511
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.728021978021978, 0.59]
# Fold: 7
# ROC_AUC: 0.655267146646457
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.6208791208791209, 0.69]
# Fold: 8
# ROC_AUC: 0.731995277449823
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8925619834710744, 0.57]
# Fold: 9
# ROC_AUC: 0.8102125147579693
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.8347107438016529, 0.79]
# Fold: 10
# ROC_AUC: 0.5507674144037781
# Estimator and parameters: Pipeline(memory=None,
#      steps=[('sampling', RandomOverSampler(random_state=42, ratio=None, return_indices=False,
#          sampling_strategy='auto')), ('clf', XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_...ate=42, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1))])
# [Confusion Matrix]: [0.9586776859504132, 0.14]
# Mean: 0.6670229848521385
# Std deviation: 0.07114164957922706
# Wall time: 5.76 s

# %%
with open('base_Over_woo_wfs.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
